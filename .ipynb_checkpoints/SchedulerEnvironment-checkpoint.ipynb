# %%
import gymnasium as gym
from gymnasium import spaces
from gymnasium.spaces import MultiDiscrete, Discrete

# %%
print(gym.__version__)
# Out:
# 0.28.1

# %%
import random

# %% [markdown]
# # Creating a Custom Environment

# %%
# make an environment
import random

class SchedulerEnvironment(gym.Env):
    def __init__(self, scenario_one = True, terminate_num = 200, mean_delay_one = 6, mean_delay_two = 4):
        self.scenario_one = scenario_one
        self.mean_delay_one = mean_delay_one
        self.mean_delay_two = mean_delay_two


        self.queue_one_incoming_packet = 0.0
        self.queue_two_incoming_packet = 0.0
        self.queue_best_effort_incoming_packet = 0.0 

        self.incoming_packets = dict(
            {
                0: self.queue_one_incoming_packet,
                1: self.queue_two_incoming_packet,
                2: self.queue_best_effort_incoming_packet

            }
            )


        self.step_counter = 0 # i.e. timeslots
        self.terminate_num = terminate_num

        # maximum size of the queue
        self.max_queue_size = 10
        
        # can adjust size of max delay in timeslots after initial observations
        MAX_DELAY = 100

        queue_sample = np.arange(self.max_queue_size)
        for i in range(self.max_queue_size):
            queue_sample[i] = MAX_DELAY

        self.observation_space = spaces.Dict( 
            {
                
                "queues": MultiDiscrete(queue_sample), 
                                
#                 boolean for timeslot delay during switch 
#                 zero for no delay, one for delay. 
                "switchCounter": Discrete(2)
                
            }
        )

        self.queue_one_delay = [] 

        self.queue_two_delay = []

        self.queue_best_effort_delay = [] 

        self.queue_delays = dict(
            {
                0: self.queue_one_delay,
                1: self.queue_two_delay,
                2: self.queue_best_effort_delay
            }
        )

        self.queue_one_removed = 0
        self.queue_two_removed = 0
        self.queue_best_effort_removed = 0

        self.removed_packets = dict(
            {
                0: self.queue_one_removed,
                1: self.queue_two_removed,
                2: self.queue_best_effort_removed
            }
        )

        self.current_state = None
        
        self.action_space = spaces.Discrete(3)
        
        self._action_to_queue = {
                0: self.queue_delays[0],
                1: self.queue_delays[1],
                2: self.queue_delays[2]
            }

    def _increment_delay(self):
        for i in range(len(self.queue_delays)):    
            for j in range(len(self.queue_delays[i])):
                self.queue_delays[i][j] += 1

            
    # def _add_delay_to_queue(self):
    #     queues = self.observation_space["queue_delay"]
    #     # this will give the index of the queue that had the packet selected
    #     selected_queue = self.action_space.sample() 
    #     for q in range(len(queues)):
    #         if (selected_queue != q):
    #             queues[q] += 1
    #         else:
    #             queues[q] = 0

    def _can_add_packets(self, packet_arrival, action ):
        # increment before evaluating arrival. 
        self.incoming_packets[action] += packet_arrival
        packet_arrived = self.incoming_packets[action] >= 1.0
        not_max_size = len(self.queue_delays[action]) < self.max_queue_size

        if packet_arrived and not_max_size:
            self.incoming_packets[action] -= 1.0
            self.queue_delays[action].append(0)                     

    def _add_packets(self):
        
        PACKET_ARRIVAL_ONE = 0.3
        PACKET_ARRIVAL_TWO = 0.25
        PACKET_ARRIVAL_BEST_EFFORT = 0.4
        
        self._can_add_packets(PACKET_ARRIVAL_ONE, 0)
        self._can_add_packets(PACKET_ARRIVAL_TWO, 1)
        self._can_add_packets(PACKET_ARRIVAL_BEST_EFFORT, 2)

        return
     
    def _modify_states(self):

        # will not calculate delay for freshly added packets. 
        self._increment_delay()
        self._add_packets()
        return 
    
    def _get_obs(self):
        return { 
            "queues": self.queue_delays
            }
    
    def _calculate_avg_delay(self, queue):
        queue_size = len(queue)
        if (queue_size == 0):
            return 0
        
        # sum
        sum = 0
        for i in range(queue_size):
            sum += queue[i]
        
        # avg
        avg = sum / queue_size
        return avg

    def _get_info(self):

        avg_one = self._calculate_avg_delay(self.queue_delays[0])
        avg_two = self._calculate_avg_delay(self.queue_delays[1])
        avg_best = self._calculate_avg_delay(self.queue_delays[2])

        # return average delays for each queue. 
        avg_mean_all_queues = [avg_one, avg_two, avg_best]
        
        # return the number of packets removed in each queue. 
        
        packets_removed = [self.removed_packets[0], self.removed_packets[1], self.removed_packets[2]]

        # return the queue num.
        return [avg_mean_all_queues, packets_removed, self.step_counter + 1]
 
    def _initialise_delays(self, queue):
        # give a random delay between 0 and 5
        size_of_queue = len(queue)
        for i in range(size_of_queue):
            queue[i] = random.randint(0, 5)

    def _set_all_zero(self):
        for i in range((3)):
            self.queue_delays[i].clear()
            self.removed_packets[i] = 0

        self.step_counter = 0
        self.current_state = None
        self.queue_one_incoming_packet = 0.0
        self.queue_two_incoming_packet = 0.0
        self.queue_best_effort_incoming_packet = 0.0 
    
    def reset(self, seed=None, options=None):

        # reset everything 
        self._set_all_zero()

        # set the size of the queue. 
        self.queue_delays[0] = self.observation_space["queues"].sample().tolist()
        self.queue_delays[1] = self.observation_space["queues"].sample().tolist()
        self.queue_delays[2] = self.observation_space["queues"].sample().tolist()

        # set seed before randomising 
        random.seed(seed)

        self._initialise_delays(self.queue_delays[0])
        self._initialise_delays(self.queue_delays[1])
        self._initialise_delays(self.queue_delays[2])

        observation = self._get_obs()
        info = self._get_info()

        if self.render_mode == "human":
            self._render_frame()

        return observation, info
    
    def _reward_function(self, action, packet_delay):
        reward = 0

        mean_delays = dict(
            {
                0: self.mean_delay_one,
                1: self.mean_delay_two
            }
        )
        
        MARGIN_OF_DELAY = 1

        # determine reward (with packet_delay)
#         (mean_delays[action] > packet_delay + MARGIN_OF_DELAY)
        if (action == 2):
        
            # reward taking the best effort queue when mean delays are adjusted
            # for priority queues.
            avg_first_queue = self._calculate_avg_delay(self.queue_delays[0])
            within_margin_first_queue = ( avg_first_queue < mean_delays[0] + MARGIN_OF_DELAY) and ( avg_first_queue > mean_delays[0] - MARGIN_OF_DELAY )
            
            avg_second_queue = self._calculate_avg_delay(self.queue_delays[1])
            within_margin_second_queue = ( avg_second_queue < mean_delays[1] + MARGIN_OF_DELAY) and ( avg_second_queue > mean_delays[1] - MARGIN_OF_DELAY )
            
            if (within_margin_first_queue and within_margin_second_queue):
                reward = 1

            # Punish for not prioritising. 
            else:
                reward = -1

        else:

            # packet delay > mean delay by the margin
            if (mean_delays[action] + MARGIN_OF_DELAY < packet_delay):
                # encourage minimising the delay for this queue.
                reward = 0

            # packet delay < mean delay by the margin
            elif (mean_delays[action] - MARGIN_OF_DELAY > packet_delay):
                # discourage minimising the delay too much.
                reward = -1

            # packet delay within margin, don't perform again. 
            else:
                reward = -1

        return reward 
    
    def _retrieve_packet(self, action):
        # retrieve the packet. 
        packet_delay = self.queue_delays[action].pop(0)
        self.removed_packets[action] += 1


        return packet_delay

    def step(self, action):
        packet_delay = 0
        # reward will be -1.
        if len(self.queue_delays[action]) == 0:
            None

        else:
            if self.scenario_one:
                packet_delay = self._retrieve_packet(action)
    
            else: 
                if (action == self.current_state):
                    packet_delay = self._retrieve_packet(action)


        # perform queue switch given the conditions.
        if not self.scenario_one:
            if (action != self.current_state):
                self.current_state = action
        
        reward = self._reward_function(action, packet_delay)
                
        self._modify_states()

        info = self._get_info()

        terminated = False
        if self.step_counter + 1 == self.terminate_num:
            terminated = True
        self.step_counter += 1

        # observation made after modifying states. 
        observation = self._get_obs()

        if self.render_mode == "human":
            self._render_frame()

        return observation, reward, terminated, False, info

    def close(self):
        if self.window is not None:
            pygame.display.quit()
            pygame.quit()

# %%
env = SchedulerEnvironment(terminate_num = 50)

# %%
def print_info(info):
    print("----------")
    print("current step =", info[2])
    print("-----")
    print("Average delay of first queue:", info[0][0])
    print("Average delay of second queue:", info[0][1])
    print("Average delay of best-effort queue:", info[0][2])
    print("-----")
    print("Packets removed from first queue:", info[1][0])
    print("Packets removed from second queue:", info[1][1])
    print("Packets removed from best-effort queue:", info[1][2])

# %%
def print_observation(observation):
    print("----------")
    print("First queue:", observation["queues"][0])
    print("Second queue:", observation["queues"][1])
    print("Best effort queue:", observation["queues"][2])

# %%
env.action_space.sample()
# Out:
# 2

# %%
obs, info = env.reset()
print_observation(obs)
print_info(info)
# Out:
# ----------
# First queue: [4, 0, 5, 2, 4, 3, 0, 4, 3, 5]
# Second queue: [1, 0, 4, 5, 2, 1, 5, 2, 5, 2]
# Best effort queue: [3, 5, 3, 1, 4, 5, 1, 1, 0, 1]
# ----------
# current step = 1
# -----
# Average delay of first queue: 3.0
# Average delay of second queue: 2.7
# Average delay of best-effort queue: 2.4
# -----
# Packets removed from first queue: 0
# Packets removed from second queue: 0
# Packets removed from best-effort queue: 0

# %%
def random_scheduler(seed = None):
    terminated = False 
    truncated = False

    # reset seeds the randomiser
    env.reset(seed)
    score = 0

    while not terminated:  
    #     random 
        action = random.randint(0, 2)
        obs, reward, terminated, truncated, info = env.step(action)
        score += reward
        print_observation(obs)
        print_info(info)
    print(score)

# %%
random_scheduler(0)
# Out:
# ----------
# First queue: [4, 4, 1, 3, 5, 4, 4, 3, 4, 3]
# Second queue: [5, 2, 5, 2, 3, 2, 1, 5, 3, 5]
# Best effort queue: [5, 2, 3, 1, 6, 1, 6, 3, 4, 0]
# ----------
# current step = 1
# -----
# Average delay of first queue: 3.5
# Average delay of second queue: 3.3
# Average delay of best-effort queue: 3.1
# -----
# Packets removed from first queue: 0
# Packets removed from second queue: 0
# Packets removed from best-effort queue: 1
# ----------
# First queue: [5, 2, 4, 6, 5, 5, 4, 5, 4]
# Second queue: [6, 3, 6, 3, 4, 3, 2, 6, 4, 6]
# Best effort queue: [6, 3, 4, 2, 7, 2, 7, 4, 5, 1]
# ----------
# current step = 2
# -----
# Average delay of first queue: 4.444444444444445
# Average delay of second queue: 4.3
# Average delay of best-effort queue: 4.1
# -----
# Packets removed from first queue: 1
# Packets removed from second queue: 0
# Packets removed from best-effort queue: 1
# ----------
# First queue: [6, 3, 5, 7, 6, 6, 5, 6, 5]
# Second queue: [4, 7, 4, 5, 4, 3, 7, 5, 7, 0]
# Best effort queue: [7, 4, 5, 3, 8, 3, 8, 5, 6, 2]
# ----------
# current step = 3
# -----
# Average delay of first queue: 5.444444444444445
# Average delay of second queue: 4.6
# Average delay of best-effort queue: 5.1
# -----
# Packets removed from first queue: 1
# Packets removed from second queue: 1
# Packets removed from best-effort queue: 1
# ----------
# First queue: [7, 4, 6, 8, 7, 7, 6, 7, 6, 0]
# Second queue: [8, 5, 6, 5, 4, 8, 6, 8, 1]
# Best effort queue: [8, 5, 6, 4, 9, 4, 9, 6, 7, 3]
# ----------
# current step = 4
# -----
# Average delay of first queue: 5.8
# Average delay of second queue: 5.666666666666667
# Average delay of best-effort queue: 6.1
# -----
# Packets removed from first queue: 1
# Packets removed from second queue: 2
# Packets removed from best-effort queue: 1
# ----------
# First queue: [8, 5, 7, 9, 8, 8, 7, 8, 7, 1]
# Second queue: [6, 7, 6, 5, 9, 7, 9, 2]
# Best effort queue: [9, 6, 7, 5, 10, 5, 10, 7, 8, 4]
# ----------
# current step = 5
# -----
# Average delay of first queue: 6.8
# Average delay of second queue: 6.375
# Average delay of best-effort queue: 7.1
# -----
# Packets removed from first queue: 1
# Packets removed from second queue: 3
# Packets removed from best-effort queue: 1
# ----------
# First queue: [9, 6, 8, 10, 9, 9, 8, 9, 8, 2]
# Second queue: [7, 8, 7, 6, 10, 8, 10, 3, 0]
# Best effort queue: [7, 8, 6, 11, 6, 11, 8, 9, 5, 0]
# ----------
# current step = 6
# -----
# Average delay of first queue: 7.8
# Average delay of second queue: 6.555555555555555
# Average delay of best-effort queue: 7.1
# -----
# Packets removed from first queue: 1
# Packets removed from second queue: 3
# Packets removed from best-effort queue: 2
# ----------
# First queue: [10, 7, 9, 11, 10, 10, 9, 10, 9, 3]
# Second queue: [8, 9, 8, 7, 11, 9, 11, 4, 1]
# Best effort queue: [9, 7, 12, 7, 12, 9, 10, 6, 1, 0]
# ----------
# current step = 7
# -----
# Average delay of first queue: 8.8
# Average delay of second queue: 7.555555555555555
# Average delay of best-effort queue: 7.3
# -----
# Packets removed from first queue: 1
# Packets removed from second queue: 3
# Packets removed from best-effort queue: 3
# ----------
# First queue: [8, 10, 12, 11, 11, 10, 11, 10, 4, 0]
# Second queue: [9, 10, 9, 8, 12, 10, 12, 5, 2]
# Best effort queue: [10, 8, 13, 8, 13, 10, 11, 7, 2, 1]
# ----------
# current step = 8
# -----
# Average delay of first queue: 8.7
# Average delay of second queue: 8.555555555555555
# Average delay of best-effort queue: 8.3
# -----
# Packets removed from first queue: 2
# Packets removed from second queue: 3
# Packets removed from best-effort queue: 3
# ----------
# First queue: [9, 11, 13, 12, 12, 11, 12, 11, 5, 1]
# Second queue: [10, 11, 10, 9, 13, 11, 13, 6, 3]
# Best effort queue: [9, 14, 9, 14, 11, 12, 8, 3, 2, 0]
# ----------
# current step = 9
# -----
# Average delay of first queue: 9.7
# Average delay of second queue: 9.555555555555555
# Average delay of best-effort queue: 8.2
# -----
# Packets removed from first queue: 2
# Packets removed from second queue: 3
# Packets removed from best-effort queue: 4
# ----------
# First queue: [10, 12, 14, 13, 13, 12, 13, 12, 6, 2]
# Second queue: [12, 11, 10, 14, 12, 14, 7, 4, 0]
# Best effort queue: [10, 15, 10, 15, 12, 13, 9, 4, 3, 1]
# ----------
# current step = 10
# -----
# Average delay of first queue: 10.7
# Average delay of second queue: 9.333333333333334
# Average delay of best-effort queue: 9.2
# -----
# Packets removed from first queue: 2
# Packets removed from second queue: 4
# Packets removed from best-effort queue: 4
# ----------
# First queue: [11, 13, 15, 14, 14, 13, 14, 13, 7, 3]
# Second queue: [12, 11, 15, 13, 15, 8, 5, 1]
# Best effort queue: [11, 16, 11, 16, 13, 14, 10, 5, 4, 2]
# ----------
# current step = 11
# -----
# Average delay of first queue: 11.7
# Average delay of second queue: 10.0
# Average delay of best-effort queue: 10.2
# -----
# Packets removed from first queue: 2
# Packets removed from second queue: 5
# Packets removed from best-effort queue: 4
# ----------
# First queue: [12, 14, 16, 15, 15, 14, 15, 14, 8, 4]
# Second queue: [13, 12, 16, 14, 16, 9, 6, 2]
# Best effort queue: [17, 12, 17, 14, 15, 11, 6, 5, 3, 0]
# ----------
# current step = 12
# -----
# Average delay of first queue: 12.7
# Average delay of second queue: 11.0
# Average delay of best-effort queue: 10.0
# -----
# Packets removed from first queue: 2
# Packets removed from second queue: 5
# Packets removed from best-effort queue: 5
# ----------
# First queue: [13, 15, 17, 16, 16, 15, 16, 15, 9, 5]
# Second queue: [13, 17, 15, 17, 10, 7, 3]
# Best effort queue: [18, 13, 18, 15, 16, 12, 7, 6, 4, 1]
# ----------
# current step = 13
# -----
# Average delay of first queue: 13.7
# Average delay of second queue: 11.714285714285714
# Average delay of best-effort queue: 11.0
# -----
# Packets removed from first queue: 2
# Packets removed from second queue: 6
# Packets removed from best-effort queue: 5
# ----------
# First queue: [16, 18, 17, 17, 16, 17, 16, 10, 6, 0]
# Second queue: [14, 18, 16, 18, 11, 8, 4, 0]
# Best effort queue: [19, 14, 19, 16, 17, 13, 8, 7, 5, 2]
# ----------
# current step = 14
# -----
# Average delay of first queue: 13.3
# Average delay of second queue: 11.125
# Average delay of best-effort queue: 12.0
# -----
# Packets removed from first queue: 3
# Packets removed from second queue: 6
# Packets removed from best-effort queue: 5
# ----------
# First queue: [17, 19, 18, 18, 17, 18, 17, 11, 7, 1]
# Second queue: [15, 19, 17, 19, 12, 9, 5, 1]
# Best effort queue: [15, 20, 17, 18, 14, 9, 8, 6, 3, 0]
# ----------
# current step = 15
# -----
# Average delay of first queue: 14.3
# Average delay of second queue: 12.125
# Average delay of best-effort queue: 11.0
# -----
# Packets removed from first queue: 3
# Packets removed from second queue: 6
# Packets removed from best-effort queue: 6
# ----------
# First queue: [20, 19, 19, 18, 19, 18, 12, 8, 2, 0]
# Second queue: [16, 20, 18, 20, 13, 10, 6, 2]
# Best effort queue: [16, 21, 18, 19, 15, 10, 9, 7, 4, 1]
# ----------
# current step = 16
# -----
# Average delay of first queue: 13.5
# Average delay of second queue: 13.125
# Average delay of best-effort queue: 12.0
# -----
# Packets removed from first queue: 4
# Packets removed from second queue: 6
# Packets removed from best-effort queue: 6
# ----------
# First queue: [20, 20, 19, 20, 19, 13, 9, 3, 1, 0]
# Second queue: [17, 21, 19, 21, 14, 11, 7, 3]
# Best effort queue: [17, 22, 19, 20, 16, 11, 10, 8, 5, 2]
# ----------
# current step = 17
# -----
# Average delay of first queue: 12.4
# Average delay of second queue: 14.125
# Average delay of best-effort queue: 13.0
# -----
# Packets removed from first queue: 5
# Packets removed from second queue: 6
# Packets removed from best-effort queue: 6
# ----------
# First queue: [21, 21, 20, 21, 20, 14, 10, 4, 2, 1]
# Second queue: [18, 22, 20, 22, 15, 12, 8, 4, 0]
# Best effort queue: [23, 20, 21, 17, 12, 11, 9, 6, 3, 0]
# ----------
# current step = 18
# -----
# Average delay of first queue: 13.4
# Average delay of second queue: 13.444444444444445
# Average delay of best-effort queue: 12.2
# -----
# Packets removed from first queue: 5
# Packets removed from second queue: 6
# Packets removed from best-effort queue: 7
# ----------
# First queue: [22, 22, 21, 22, 21, 15, 11, 5, 3, 2]
# Second queue: [23, 21, 23, 16, 13, 9, 5, 1]
# Best effort queue: [24, 21, 22, 18, 13, 12, 10, 7, 4, 1]
# ----------
# current step = 19
# -----
# Average delay of first queue: 14.4
# Average delay of second queue: 13.875
# Average delay of best-effort queue: 13.2
# -----
# Packets removed from first queue: 5
# Packets removed from second queue: 7
# Packets removed from best-effort queue: 7
# ----------
# First queue: [23, 23, 22, 23, 22, 16, 12, 6, 4, 3]
# Second queue: [24, 22, 24, 17, 14, 10, 6, 2]
# Best effort queue: [22, 23, 19, 14, 13, 11, 8, 5, 2, 0]
# ----------
# current step = 20
# -----
# Average delay of first queue: 15.4
# Average delay of second queue: 14.875
# Average delay of best-effort queue: 11.7
# -----
# Packets removed from first queue: 5
# Packets removed from second queue: 7
# Packets removed from best-effort queue: 8
# ----------
# First queue: [24, 24, 23, 24, 23, 17, 13, 7, 5, 4]
# Second queue: [25, 23, 25, 18, 15, 11, 7, 3]
# Best effort queue: [24, 20, 15, 14, 12, 9, 6, 3, 1, 0]
# ----------
# current step = 21
# -----
# Average delay of first queue: 16.4
# Average delay of second queue: 15.875
# Average delay of best-effort queue: 10.4
# -----
# Packets removed from first queue: 5
# Packets removed from second queue: 7
# Packets removed from best-effort queue: 9
# ----------
# First queue: [25, 25, 24, 25, 24, 18, 14, 8, 6, 5]
# Second queue: [26, 24, 26, 19, 16, 12, 8, 4, 0]
# Best effort queue: [21, 16, 15, 13, 10, 7, 4, 2, 1, 0]
# ----------
# current step = 22
# -----
# Average delay of first queue: 17.4
# Average delay of second queue: 15.0
# Average delay of best-effort queue: 8.9
# -----
# Packets removed from first queue: 5
# Packets removed from second queue: 7
# Packets removed from best-effort queue: 10
# ----------
# First queue: [26, 25, 26, 25, 19, 15, 9, 7, 6, 0]
# Second queue: [27, 25, 27, 20, 17, 13, 9, 5, 1]
# Best effort queue: [22, 17, 16, 14, 11, 8, 5, 3, 2, 1]
# ----------
# current step = 23
# -----
# Average delay of first queue: 15.8
# Average delay of second queue: 16.0
# Average delay of best-effort queue: 9.9
# -----
# Packets removed from first queue: 6
# Packets removed from second queue: 7
# Packets removed from best-effort queue: 10
# ----------
# First queue: [27, 26, 27, 26, 20, 16, 10, 8, 7, 1]
# Second queue: [28, 26, 28, 21, 18, 14, 10, 6, 2]
# Best effort queue: [18, 17, 15, 12, 9, 6, 4, 3, 2, 0]
# ----------
# current step = 24
# -----
# Average delay of first queue: 16.8
# Average delay of second queue: 17.0
# Average delay of best-effort queue: 8.6
# -----
# Packets removed from first queue: 6
# Packets removed from second queue: 7
# Packets removed from best-effort queue: 11
# ----------
# First queue: [28, 27, 28, 27, 21, 17, 11, 9, 8, 2]
# Second queue: [27, 29, 22, 19, 15, 11, 7, 3]
# Best effort queue: [19, 18, 16, 13, 10, 7, 5, 4, 3, 1]
# ----------
# current step = 25
# -----
# Average delay of first queue: 17.8
# Average delay of second queue: 16.625
# Average delay of best-effort queue: 9.6
# -----
# Packets removed from first queue: 6
# Packets removed from second queue: 8
# Packets removed from best-effort queue: 11
# ----------
# First queue: [29, 28, 29, 28, 22, 18, 12, 10, 9, 3]
# Second queue: [30, 23, 20, 16, 12, 8, 4, 0]
# Best effort queue: [20, 19, 17, 14, 11, 8, 6, 5, 4, 2]
# ----------
# current step = 26
# -----
# Average delay of first queue: 18.8
# Average delay of second queue: 14.125
# Average delay of best-effort queue: 10.6
# -----
# Packets removed from first queue: 6
# Packets removed from second queue: 9
# Packets removed from best-effort queue: 11
# ----------
# First queue: [29, 30, 29, 23, 19, 13, 11, 10, 4, 0]
# Second queue: [31, 24, 21, 17, 13, 9, 5, 1]
# Best effort queue: [21, 20, 18, 15, 12, 9, 7, 6, 5, 3]
# ----------
# current step = 27
# -----
# Average delay of first queue: 16.8
# Average delay of second queue: 15.125
# Average delay of best-effort queue: 11.6
# -----
# Packets removed from first queue: 7
# Packets removed from second queue: 9
# Packets removed from best-effort queue: 11
# ----------
# First queue: [30, 31, 30, 24, 20, 14, 12, 11, 5, 1]
# Second queue: [32, 25, 22, 18, 14, 10, 6, 2]
# Best effort queue: [21, 19, 16, 13, 10, 8, 7, 6, 4, 0]
# ----------
# current step = 28
# -----
# Average delay of first queue: 17.8
# Average delay of second queue: 16.125
# Average delay of best-effort queue: 10.4
# -----
# Packets removed from first queue: 7
# Packets removed from second queue: 9
# Packets removed from best-effort queue: 12
# ----------
# First queue: [31, 32, 31, 25, 21, 15, 13, 12, 6, 2]
# Second queue: [26, 23, 19, 15, 11, 7, 3]
# Best effort queue: [22, 20, 17, 14, 11, 9, 8, 7, 5, 1]
# ----------
# current step = 29
# -----
# Average delay of first queue: 18.8
# Average delay of second queue: 14.857142857142858
# Average delay of best-effort queue: 11.4
# -----
# Packets removed from first queue: 7
# Packets removed from second queue: 10
# Packets removed from best-effort queue: 12
# ----------
# First queue: [32, 33, 32, 26, 22, 16, 14, 13, 7, 3]
# Second queue: [27, 24, 20, 16, 12, 8, 4, 0]
# Best effort queue: [21, 18, 15, 12, 10, 9, 8, 6, 2, 0]
# ----------
# current step = 30
# -----
# Average delay of first queue: 19.8
# Average delay of second queue: 13.875
# Average delay of best-effort queue: 10.1
# -----
# Packets removed from first queue: 7
# Packets removed from second queue: 10
# Packets removed from best-effort queue: 13
# ----------
# First queue: [34, 33, 27, 23, 17, 15, 14, 8, 4, 0]
# Second queue: [28, 25, 21, 17, 13, 9, 5, 1]
# Best effort queue: [22, 19, 16, 13, 11, 10, 9, 7, 3, 1]
# ----------
# current step = 31
# -----
# Average delay of first queue: 17.5
# Average delay of second queue: 14.875
# Average delay of best-effort queue: 11.1
# -----
# Packets removed from first queue: 8
# Packets removed from second queue: 10
# Packets removed from best-effort queue: 13
# ----------
# First queue: [34, 28, 24, 18, 16, 15, 9, 5, 1, 0]
# Second queue: [29, 26, 22, 18, 14, 10, 6, 2]
# Best effort queue: [23, 20, 17, 14, 12, 11, 10, 8, 4, 2]
# ----------
# current step = 32
# -----
# Average delay of first queue: 15.0
# Average delay of second queue: 15.875
# Average delay of best-effort queue: 12.1
# -----
# Packets removed from first queue: 9
# Packets removed from second queue: 10
# Packets removed from best-effort queue: 13
# ----------
# First queue: [35, 29, 25, 19, 17, 16, 10, 6, 2, 1]
# Second queue: [30, 27, 23, 19, 15, 11, 7, 3]
# Best effort queue: [21, 18, 15, 13, 12, 11, 9, 5, 3, 0]
# ----------
# current step = 33
# -----
# Average delay of first queue: 16.0
# Average delay of second queue: 16.875
# Average delay of best-effort queue: 10.7
# -----
# Packets removed from first queue: 9
# Packets removed from second queue: 10
# Packets removed from best-effort queue: 14
# ----------
# First queue: [30, 26, 20, 18, 17, 11, 7, 3, 2, 0]
# Second queue: [31, 28, 24, 20, 16, 12, 8, 4, 0]
# Best effort queue: [22, 19, 16, 14, 13, 12, 10, 6, 4, 1]
# ----------
# current step = 34
# -----
# Average delay of first queue: 13.4
# Average delay of second queue: 15.88888888888889
# Average delay of best-effort queue: 11.7
# -----
# Packets removed from first queue: 10
# Packets removed from second queue: 10
# Packets removed from best-effort queue: 14
# ----------
# First queue: [27, 21, 19, 18, 12, 8, 4, 3, 1]
# Second queue: [32, 29, 25, 21, 17, 13, 9, 5, 1]
# Best effort queue: [23, 20, 17, 15, 14, 13, 11, 7, 5, 2]
# ----------
# current step = 35
# -----
# Average delay of first queue: 12.555555555555555
# Average delay of second queue: 16.88888888888889
# Average delay of best-effort queue: 12.7
# -----
# Packets removed from first queue: 11
# Packets removed from second queue: 10
# Packets removed from best-effort queue: 14
# ----------
# First queue: [22, 20, 19, 13, 9, 5, 4, 2]
# Second queue: [33, 30, 26, 22, 18, 14, 10, 6, 2]
# Best effort queue: [24, 21, 18, 16, 15, 14, 12, 8, 6, 3]
# ----------
# current step = 36
# -----
# Average delay of first queue: 11.75
# Average delay of second queue: 17.88888888888889
# Average delay of best-effort queue: 13.7
# -----
# Packets removed from first queue: 12
# Packets removed from second queue: 10
# Packets removed from best-effort queue: 14
# ----------
# First queue: [23, 21, 20, 14, 10, 6, 5, 3, 0]
# Second queue: [34, 31, 27, 23, 19, 15, 11, 7, 3]
# Best effort queue: [22, 19, 17, 16, 15, 13, 9, 7, 4, 0]
# ----------
# current step = 37
# -----
# Average delay of first queue: 11.333333333333334
# Average delay of second queue: 18.88888888888889
# Average delay of best-effort queue: 12.2
# -----
# Packets removed from first queue: 12
# Packets removed from second queue: 10
# Packets removed from best-effort queue: 15
# ----------
# First queue: [24, 22, 21, 15, 11, 7, 6, 4, 1]
# Second queue: [32, 28, 24, 20, 16, 12, 8, 4, 0]
# Best effort queue: [23, 20, 18, 17, 16, 14, 10, 8, 5, 1]
# ----------
# current step = 38
# -----
# Average delay of first queue: 12.333333333333334
# Average delay of second queue: 16.0
# Average delay of best-effort queue: 13.2
# -----
# Packets removed from first queue: 12
# Packets removed from second queue: 11
# Packets removed from best-effort queue: 15
# ----------
# First queue: [23, 22, 16, 12, 8, 7, 5, 2]
# Second queue: [33, 29, 25, 21, 17, 13, 9, 5, 1]
# Best effort queue: [24, 21, 19, 18, 17, 15, 11, 9, 6, 2]
# ----------
# current step = 39
# -----
# Average delay of first queue: 11.875
# Average delay of second queue: 17.0
# Average delay of best-effort queue: 14.2
# -----
# Packets removed from first queue: 13
# Packets removed from second queue: 11
# Packets removed from best-effort queue: 15
# ----------
# First queue: [23, 17, 13, 9, 8, 6, 3, 0]
# Second queue: [34, 30, 26, 22, 18, 14, 10, 6, 2]
# Best effort queue: [25, 22, 20, 19, 18, 16, 12, 10, 7, 3]
# ----------
# current step = 40
# -----
# Average delay of first queue: 9.875
# Average delay of second queue: 18.0
# Average delay of best-effort queue: 15.2
# -----
# Packets removed from first queue: 14
# Packets removed from second queue: 11
# Packets removed from best-effort queue: 15
# ----------
# First queue: [24, 18, 14, 10, 9, 7, 4, 1]
# Second queue: [31, 27, 23, 19, 15, 11, 7, 3]
# Best effort queue: [26, 23, 21, 20, 19, 17, 13, 11, 8, 4]
# ----------
# current step = 41
# -----
# Average delay of first queue: 10.875
# Average delay of second queue: 17.0
# Average delay of best-effort queue: 16.2
# -----
# Packets removed from first queue: 14
# Packets removed from second queue: 12
# Packets removed from best-effort queue: 15
# ----------
# First queue: [25, 19, 15, 11, 10, 8, 5, 2]
# Second queue: [32, 28, 24, 20, 16, 12, 8, 4, 0]
# Best effort queue: [24, 22, 21, 20, 18, 14, 12, 9, 5, 0]
# ----------
# current step = 42
# -----
# Average delay of first queue: 11.875
# Average delay of second queue: 16.0
# Average delay of best-effort queue: 14.5
# -----
# Packets removed from first queue: 14
# Packets removed from second queue: 12
# Packets removed from best-effort queue: 16
# ----------
# First queue: [26, 20, 16, 12, 11, 9, 6, 3]
# Second queue: [29, 25, 21, 17, 13, 9, 5, 1]
# Best effort queue: [25, 23, 22, 21, 19, 15, 13, 10, 6, 1]
# ----------
# current step = 43
# -----
# Average delay of first queue: 12.875
# Average delay of second queue: 15.0
# Average delay of best-effort queue: 15.5
# -----
# Packets removed from first queue: 14
# Packets removed from second queue: 13
# Packets removed from best-effort queue: 16
# ----------
# First queue: [21, 17, 13, 12, 10, 7, 4, 0]
# Second queue: [30, 26, 22, 18, 14, 10, 6, 2]
# Best effort queue: [26, 24, 23, 22, 20, 16, 14, 11, 7, 2]
# ----------
# current step = 44
# -----
# Average delay of first queue: 10.5
# Average delay of second queue: 16.0
# Average delay of best-effort queue: 16.5
# -----
# Packets removed from first queue: 15
# Packets removed from second queue: 13
# Packets removed from best-effort queue: 16
# ----------
# First queue: [22, 18, 14, 13, 11, 8, 5, 1]
# Second queue: [27, 23, 19, 15, 11, 7, 3]
# Best effort queue: [27, 25, 24, 23, 21, 17, 15, 12, 8, 3]
# ----------
# current step = 45
# -----
# Average delay of first queue: 11.5
# Average delay of second queue: 15.0
# Average delay of best-effort queue: 17.5
# -----
# Packets removed from first queue: 15
# Packets removed from second queue: 14
# Packets removed from best-effort queue: 16
# ----------
# First queue: [23, 19, 15, 14, 12, 9, 6, 2]
# Second queue: [28, 24, 20, 16, 12, 8, 4, 0]
# Best effort queue: [26, 25, 24, 22, 18, 16, 13, 9, 4, 0]
# ----------
# current step = 46
# -----
# Average delay of first queue: 12.5
# Average delay of second queue: 14.0
# Average delay of best-effort queue: 15.7
# -----
# Packets removed from first queue: 15
# Packets removed from second queue: 14
# Packets removed from best-effort queue: 17
# ----------
# First queue: [24, 20, 16, 15, 13, 10, 7, 3, 0]
# Second queue: [25, 21, 17, 13, 9, 5, 1]
# Best effort queue: [27, 26, 25, 23, 19, 17, 14, 10, 5, 1]
# ----------
# current step = 47
# -----
# Average delay of first queue: 12.0
# Average delay of second queue: 13.0
# Average delay of best-effort queue: 16.7
# -----
# Packets removed from first queue: 15
# Packets removed from second queue: 15
# Packets removed from best-effort queue: 17
# ----------
# First queue: [25, 21, 17, 16, 14, 11, 8, 4, 1]
# Second queue: [26, 22, 18, 14, 10, 6, 2]
# Best effort queue: [27, 26, 24, 20, 18, 15, 11, 6, 2, 0]
# ----------
# current step = 48
# -----
# Average delay of first queue: 13.0
# Average delay of second queue: 14.0
# Average delay of best-effort queue: 14.9
# -----
# Packets removed from first queue: 15
# Packets removed from second queue: 15
# Packets removed from best-effort queue: 18
# ----------
# First queue: [22, 18, 17, 15, 12, 9, 5, 2]
# Second queue: [27, 23, 19, 15, 11, 7, 3]
# Best effort queue: [28, 27, 25, 21, 19, 16, 12, 7, 3, 1]
# ----------
# current step = 49
# -----
# Average delay of first queue: 12.5
# Average delay of second queue: 15.0
# Average delay of best-effort queue: 15.9
# -----
# Packets removed from first queue: 16
# Packets removed from second queue: 15
# Packets removed from best-effort queue: 18
# ----------
# First queue: [23, 19, 18, 16, 13, 10, 6, 3, 0]
# Second queue: [28, 24, 20, 16, 12, 8, 4, 0]
# Best effort queue: [28, 26, 22, 20, 17, 13, 8, 4, 2, 0]
# ----------
# current step = 50
# -----
# Average delay of first queue: 12.0
# Average delay of second queue: 14.0
# Average delay of best-effort queue: 14.0
# -----
# Packets removed from first queue: 16
# Packets removed from second queue: 15
# Packets removed from best-effort queue: 19
# -21

# %%
random_scheduler(1)
# Out:
# ----------
# First queue: [2, 5, 1, 3, 1, 4, 4, 4, 6, 4]
# Second queue: [2, 1, 4, 1, 4, 4, 5, 1, 6, 4]
# Best effort queue: [6, 2, 5, 1, 3, 1, 1, 1, 6, 0]
# ----------
# current step = 1
# -----
# Average delay of first queue: 3.4
# Average delay of second queue: 3.2
# Average delay of best-effort queue: 2.6
# -----
# Packets removed from first queue: 0
# Packets removed from second queue: 0
# Packets removed from best-effort queue: 1
# ----------
# First queue: [6, 2, 4, 2, 5, 5, 5, 7, 5]
# Second queue: [3, 2, 5, 2, 5, 5, 6, 2, 7, 5]
# Best effort queue: [7, 3, 6, 2, 4, 2, 2, 2, 7, 1]
# ----------
# current step = 2
# -----
# Average delay of first queue: 4.555555555555555
# Average delay of second queue: 4.2
# Average delay of best-effort queue: 3.6
# -----
# Packets removed from first queue: 1
# Packets removed from second queue: 0
# Packets removed from best-effort queue: 1
# ----------
# First queue: [7, 3, 5, 3, 6, 6, 6, 8, 6]
# Second queue: [3, 6, 3, 6, 6, 7, 3, 8, 6]
# Best effort queue: [8, 4, 7, 3, 5, 3, 3, 3, 8, 2]
# ----------
# current step = 3
# -----
# Average delay of first queue: 5.555555555555555
# Average delay of second queue: 5.333333333333333
# Average delay of best-effort queue: 4.6
# -----
# Packets removed from first queue: 1
# Packets removed from second queue: 1
# Packets removed from best-effort queue: 1
# ----------
# First queue: [8, 4, 6, 4, 7, 7, 7, 9, 7, 0]
# Second queue: [4, 7, 4, 7, 7, 8, 4, 9, 7, 0]
# Best effort queue: [5, 8, 4, 6, 4, 4, 4, 9, 3, 0]
# ----------
# current step = 4
# -----
# Average delay of first queue: 5.9
# Average delay of second queue: 5.7
# Average delay of best-effort queue: 4.7
# -----
# Packets removed from first queue: 1
# Packets removed from second queue: 1
# Packets removed from best-effort queue: 2
# ----------
# First queue: [5, 7, 5, 8, 8, 8, 10, 8, 1]
# Second queue: [5, 8, 5, 8, 8, 9, 5, 10, 8, 1]
# Best effort queue: [6, 9, 5, 7, 5, 5, 5, 10, 4, 1]
# ----------
# current step = 5
# -----
# Average delay of first queue: 6.666666666666667
# Average delay of second queue: 6.7
# Average delay of best-effort queue: 5.7
# -----
# Packets removed from first queue: 2
# Packets removed from second queue: 1
# Packets removed from best-effort queue: 2
# ----------
# First queue: [6, 8, 6, 9, 9, 9, 11, 9, 2]
# Second queue: [9, 6, 9, 9, 10, 6, 11, 9, 2]
# Best effort queue: [7, 10, 6, 8, 6, 6, 6, 11, 5, 2]
# ----------
# current step = 6
# -----
# Average delay of first queue: 7.666666666666667
# Average delay of second queue: 7.888888888888889
# Average delay of best-effort queue: 6.7
# -----
# Packets removed from first queue: 2
# Packets removed from second queue: 2
# Packets removed from best-effort queue: 2
# ----------
# First queue: [7, 9, 7, 10, 10, 10, 12, 10, 3, 0]
# Second queue: [10, 7, 10, 10, 11, 7, 12, 10, 3]
# Best effort queue: [11, 7, 9, 7, 7, 7, 12, 6, 3, 0]
# ----------
# current step = 7
# -----
# Average delay of first queue: 7.8
# Average delay of second queue: 8.88888888888889
# Average delay of best-effort queue: 6.9
# -----
# Packets removed from first queue: 2
# Packets removed from second queue: 2
# Packets removed from best-effort queue: 3
# ----------
# First queue: [10, 8, 11, 11, 11, 13, 11, 4, 1]
# Second queue: [11, 8, 11, 11, 12, 8, 13, 11, 4, 0]
# Best effort queue: [12, 8, 10, 8, 8, 8, 13, 7, 4, 1]
# ----------
# current step = 8
# -----
# Average delay of first queue: 8.88888888888889
# Average delay of second queue: 8.9
# Average delay of best-effort queue: 7.9
# -----
# Packets removed from first queue: 3
# Packets removed from second queue: 2
# Packets removed from best-effort queue: 3
# ----------
# First queue: [11, 9, 12, 12, 12, 14, 12, 5, 2]
# Second queue: [12, 9, 12, 12, 13, 9, 14, 12, 5, 1]
# Best effort queue: [9, 11, 9, 9, 9, 14, 8, 5, 2, 0]
# ----------
# current step = 9
# -----
# Average delay of first queue: 9.88888888888889
# Average delay of second queue: 9.9
# Average delay of best-effort queue: 7.6
# -----
# Packets removed from first queue: 3
# Packets removed from second queue: 2
# Packets removed from best-effort queue: 4
# ----------
# First queue: [10, 13, 13, 13, 15, 13, 6, 3, 0]
# Second queue: [13, 10, 13, 13, 14, 10, 15, 13, 6, 2]
# Best effort queue: [10, 12, 10, 10, 10, 15, 9, 6, 3, 1]
# ----------
# current step = 10
# -----
# Average delay of first queue: 9.555555555555555
# Average delay of second queue: 10.9
# Average delay of best-effort queue: 8.6
# -----
# Packets removed from first queue: 4
# Packets removed from second queue: 2
# Packets removed from best-effort queue: 4
# ----------
# First queue: [11, 14, 14, 14, 16, 14, 7, 4, 1]
# Second queue: [11, 14, 14, 15, 11, 16, 14, 7, 3]
# Best effort queue: [11, 13, 11, 11, 11, 16, 10, 7, 4, 2]
# ----------
# current step = 11
# -----
# Average delay of first queue: 10.555555555555555
# Average delay of second queue: 11.666666666666666
# Average delay of best-effort queue: 9.6
# -----
# Packets removed from first queue: 4
# Packets removed from second queue: 3
# Packets removed from best-effort queue: 4
# ----------
# First queue: [12, 15, 15, 15, 17, 15, 8, 5, 2]
# Second queue: [15, 15, 16, 12, 17, 15, 8, 4, 0]
# Best effort queue: [12, 14, 12, 12, 12, 17, 11, 8, 5, 3]
# ----------
# current step = 12
# -----
# Average delay of first queue: 11.555555555555555
# Average delay of second queue: 11.333333333333334
# Average delay of best-effort queue: 10.6
# -----
# Packets removed from first queue: 4
# Packets removed from second queue: 4
# Packets removed from best-effort queue: 4
# ----------
# First queue: [13, 16, 16, 16, 18, 16, 9, 6, 3]
# Second queue: [16, 16, 17, 13, 18, 16, 9, 5, 1]
# Best effort queue: [15, 13, 13, 13, 18, 12, 9, 6, 4, 0]
# ----------
# current step = 13
# -----
# Average delay of first queue: 12.555555555555555
# Average delay of second queue: 12.333333333333334
# Average delay of best-effort queue: 10.3
# -----
# Packets removed from first queue: 4
# Packets removed from second queue: 4
# Packets removed from best-effort queue: 5
# ----------
# First queue: [17, 17, 17, 19, 17, 10, 7, 4, 0]
# Second queue: [17, 17, 18, 14, 19, 17, 10, 6, 2]
# Best effort queue: [16, 14, 14, 14, 19, 13, 10, 7, 5, 1]
# ----------
# current step = 14
# -----
# Average delay of first queue: 12.0
# Average delay of second queue: 13.333333333333334
# Average delay of best-effort queue: 11.3
# -----
# Packets removed from first queue: 5
# Packets removed from second queue: 4
# Packets removed from best-effort queue: 5
# ----------
# First queue: [18, 18, 18, 20, 18, 11, 8, 5, 1]
# Second queue: [18, 19, 15, 20, 18, 11, 7, 3]
# Best effort queue: [17, 15, 15, 15, 20, 14, 11, 8, 6, 2]
# ----------
# current step = 15
# -----
# Average delay of first queue: 13.0
# Average delay of second queue: 13.875
# Average delay of best-effort queue: 12.3
# -----
# Packets removed from first queue: 5
# Packets removed from second queue: 5
# Packets removed from best-effort queue: 5
# ----------
# First queue: [19, 19, 21, 19, 12, 9, 6, 2]
# Second queue: [19, 20, 16, 21, 19, 12, 8, 4, 0]
# Best effort queue: [18, 16, 16, 16, 21, 15, 12, 9, 7, 3]
# ----------
# current step = 16
# -----
# Average delay of first queue: 13.375
# Average delay of second queue: 13.222222222222221
# Average delay of best-effort queue: 13.3
# -----
# Packets removed from first queue: 6
# Packets removed from second queue: 5
# Packets removed from best-effort queue: 5
# ----------
# First queue: [20, 20, 22, 20, 13, 10, 7, 3, 0]
# Second queue: [20, 21, 17, 22, 20, 13, 9, 5, 1]
# Best effort queue: [17, 17, 17, 22, 16, 13, 10, 8, 4, 0]
# ----------
# current step = 17
# -----
# Average delay of first queue: 12.777777777777779
# Average delay of second queue: 14.222222222222221
# Average delay of best-effort queue: 12.4
# -----
# Packets removed from first queue: 6
# Packets removed from second queue: 5
# Packets removed from best-effort queue: 6
# ----------
# First queue: [21, 23, 21, 14, 11, 8, 4, 1]
# Second queue: [21, 22, 18, 23, 21, 14, 10, 6, 2]
# Best effort queue: [18, 18, 18, 23, 17, 14, 11, 9, 5, 1]
# ----------
# current step = 18
# -----
# Average delay of first queue: 12.875
# Average delay of second queue: 15.222222222222221
# Average delay of best-effort queue: 13.4
# -----
# Packets removed from first queue: 7
# Packets removed from second queue: 5
# Packets removed from best-effort queue: 6
# ----------
# First queue: [22, 24, 22, 15, 12, 9, 5, 2]
# Second queue: [23, 19, 24, 22, 15, 11, 7, 3]
# Best effort queue: [19, 19, 19, 24, 18, 15, 12, 10, 6, 2]
# ----------
# current step = 19
# -----
# Average delay of first queue: 13.875
# Average delay of second queue: 15.5
# Average delay of best-effort queue: 14.4
# -----
# Packets removed from first queue: 7
# Packets removed from second queue: 6
# Packets removed from best-effort queue: 6
# ----------
# First queue: [23, 25, 23, 16, 13, 10, 6, 3, 0]
# Second queue: [20, 25, 23, 16, 12, 8, 4, 0]
# Best effort queue: [20, 20, 20, 25, 19, 16, 13, 11, 7, 3]
# ----------
# current step = 20
# -----
# Average delay of first queue: 13.222222222222221
# Average delay of second queue: 13.5
# Average delay of best-effort queue: 15.4
# -----
# Packets removed from first queue: 7
# Packets removed from second queue: 7
# Packets removed from best-effort queue: 6
# ----------
# First queue: [26, 24, 17, 14, 11, 7, 4, 1]
# Second queue: [21, 26, 24, 17, 13, 9, 5, 1]
# Best effort queue: [21, 21, 21, 26, 20, 17, 14, 12, 8, 4]
# ----------
# current step = 21
# -----
# Average delay of first queue: 13.0
# Average delay of second queue: 14.5
# Average delay of best-effort queue: 16.4
# -----
# Packets removed from first queue: 8
# Packets removed from second queue: 7
# Packets removed from best-effort queue: 6
# ----------
# First queue: [27, 25, 18, 15, 12, 8, 5, 2]
# Second queue: [27, 25, 18, 14, 10, 6, 2]
# Best effort queue: [22, 22, 22, 27, 21, 18, 15, 13, 9, 5]
# ----------
# current step = 22
# -----
# Average delay of first queue: 14.0
# Average delay of second queue: 14.571428571428571
# Average delay of best-effort queue: 17.4
# -----
# Packets removed from first queue: 8
# Packets removed from second queue: 8
# Packets removed from best-effort queue: 6
# ----------
# First queue: [28, 26, 19, 16, 13, 9, 6, 3]
# Second queue: [28, 26, 19, 15, 11, 7, 3]
# Best effort queue: [23, 23, 28, 22, 19, 16, 14, 10, 6, 0]
# ----------
# current step = 23
# -----
# Average delay of first queue: 15.0
# Average delay of second queue: 15.571428571428571
# Average delay of best-effort queue: 16.1
# -----
# Packets removed from first queue: 8
# Packets removed from second queue: 8
# Packets removed from best-effort queue: 7
# ----------
# First queue: [29, 27, 20, 17, 14, 10, 7, 4, 0]
# Second queue: [29, 27, 20, 16, 12, 8, 4, 0]
# Best effort queue: [24, 29, 23, 20, 17, 15, 11, 7, 1, 0]
# ----------
# current step = 24
# -----
# Average delay of first queue: 14.222222222222221
# Average delay of second queue: 14.5
# Average delay of best-effort queue: 14.7
# -----
# Packets removed from first queue: 8
# Packets removed from second queue: 8
# Packets removed from best-effort queue: 8
# ----------
# First queue: [28, 21, 18, 15, 11, 8, 5, 1]
# Second queue: [30, 28, 21, 17, 13, 9, 5, 1]
# Best effort queue: [25, 30, 24, 21, 18, 16, 12, 8, 2, 1]
# ----------
# current step = 25
# -----
# Average delay of first queue: 13.375
# Average delay of second queue: 15.5
# Average delay of best-effort queue: 15.7
# -----
# Packets removed from first queue: 9
# Packets removed from second queue: 8
# Packets removed from best-effort queue: 8
# ----------
# First queue: [22, 19, 16, 12, 9, 6, 2]
# Second queue: [31, 29, 22, 18, 14, 10, 6, 2]
# Best effort queue: [26, 31, 25, 22, 19, 17, 13, 9, 3, 2]
# ----------
# current step = 26
# -----
# Average delay of first queue: 12.285714285714286
# Average delay of second queue: 16.5
# Average delay of best-effort queue: 16.7
# -----
# Packets removed from first queue: 10
# Packets removed from second queue: 8
# Packets removed from best-effort queue: 8
# ----------
# First queue: [23, 20, 17, 13, 10, 7, 3, 0]
# Second queue: [32, 30, 23, 19, 15, 11, 7, 3]
# Best effort queue: [32, 26, 23, 20, 18, 14, 10, 4, 3, 0]
# ----------
# current step = 27
# -----
# Average delay of first queue: 11.625
# Average delay of second queue: 17.5
# Average delay of best-effort queue: 15.0
# -----
# Packets removed from first queue: 10
# Packets removed from second queue: 8
# Packets removed from best-effort queue: 9
# ----------
# First queue: [24, 21, 18, 14, 11, 8, 4, 1]
# Second queue: [33, 31, 24, 20, 16, 12, 8, 4, 0]
# Best effort queue: [27, 24, 21, 19, 15, 11, 5, 4, 1, 0]
# ----------
# current step = 28
# -----
# Average delay of first queue: 12.625
# Average delay of second queue: 16.444444444444443
# Average delay of best-effort queue: 12.7
# -----
# Packets removed from first queue: 10
# Packets removed from second queue: 8
# Packets removed from best-effort queue: 10
# ----------
# First queue: [25, 22, 19, 15, 12, 9, 5, 2]
# Second queue: [32, 25, 21, 17, 13, 9, 5, 1]
# Best effort queue: [28, 25, 22, 20, 16, 12, 6, 5, 2, 1]
# ----------
# current step = 29
# -----
# Average delay of first queue: 13.625
# Average delay of second queue: 15.375
# Average delay of best-effort queue: 13.7
# -----
# Packets removed from first queue: 10
# Packets removed from second queue: 9
# Packets removed from best-effort queue: 10
# ----------
# First queue: [23, 20, 16, 13, 10, 6, 3, 0]
# Second queue: [33, 26, 22, 18, 14, 10, 6, 2]
# Best effort queue: [29, 26, 23, 21, 17, 13, 7, 6, 3, 2]
# ----------
# current step = 30
# -----
# Average delay of first queue: 11.375
# Average delay of second queue: 16.375
# Average delay of best-effort queue: 14.7
# -----
# Packets removed from first queue: 11
# Packets removed from second queue: 9
# Packets removed from best-effort queue: 10
# ----------
# First queue: [24, 21, 17, 14, 11, 7, 4, 1]
# Second queue: [34, 27, 23, 19, 15, 11, 7, 3]
# Best effort queue: [27, 24, 22, 18, 14, 8, 7, 4, 3, 0]
# ----------
# current step = 31
# -----
# Average delay of first queue: 12.375
# Average delay of second queue: 17.375
# Average delay of best-effort queue: 12.7
# -----
# Packets removed from first queue: 11
# Packets removed from second queue: 9
# Packets removed from best-effort queue: 11
# ----------
# First queue: [25, 22, 18, 15, 12, 8, 5, 2]
# Second queue: [28, 24, 20, 16, 12, 8, 4, 0]
# Best effort queue: [28, 25, 23, 19, 15, 9, 8, 5, 4, 1]
# ----------
# current step = 32
# -----
# Average delay of first queue: 13.375
# Average delay of second queue: 14.0
# Average delay of best-effort queue: 13.7
# -----
# Packets removed from first queue: 11
# Packets removed from second queue: 10
# Packets removed from best-effort queue: 11
# ----------
# First queue: [26, 23, 19, 16, 13, 9, 6, 3]
# Second queue: [29, 25, 21, 17, 13, 9, 5, 1]
# Best effort queue: [26, 24, 20, 16, 10, 9, 6, 5, 2, 0]
# ----------
# current step = 33
# -----
# Average delay of first queue: 14.375
# Average delay of second queue: 15.0
# Average delay of best-effort queue: 11.8
# -----
# Packets removed from first queue: 11
# Packets removed from second queue: 10
# Packets removed from best-effort queue: 12
# ----------
# First queue: [27, 24, 20, 17, 14, 10, 7, 4, 0]
# Second queue: [30, 26, 22, 18, 14, 10, 6, 2]
# Best effort queue: [25, 21, 17, 11, 10, 7, 6, 3, 1, 0]
# ----------
# current step = 34
# -----
# Average delay of first queue: 13.666666666666666
# Average delay of second queue: 16.0
# Average delay of best-effort queue: 10.1
# -----
# Packets removed from first queue: 11
# Packets removed from second queue: 10
# Packets removed from best-effort queue: 13
# ----------
# First queue: [28, 25, 21, 18, 15, 11, 8, 5, 1]
# Second queue: [31, 27, 23, 19, 15, 11, 7, 3]
# Best effort queue: [22, 18, 12, 11, 8, 7, 4, 2, 1, 0]
# ----------
# current step = 35
# -----
# Average delay of first queue: 14.666666666666666
# Average delay of second queue: 17.0
# Average delay of best-effort queue: 8.5
# -----
# Packets removed from first queue: 11
# Packets removed from second queue: 10
# Packets removed from best-effort queue: 14
# ----------
# First queue: [29, 26, 22, 19, 16, 12, 9, 6, 2]
# Second queue: [28, 24, 20, 16, 12, 8, 4, 0]
# Best effort queue: [23, 19, 13, 12, 9, 8, 5, 3, 2, 1]
# ----------
# current step = 36
# -----
# Average delay of first queue: 15.666666666666666
# Average delay of second queue: 14.0
# Average delay of best-effort queue: 9.5
# -----
# Packets removed from first queue: 11
# Packets removed from second queue: 11
# Packets removed from best-effort queue: 14
# ----------
# First queue: [30, 27, 23, 20, 17, 13, 10, 7, 3, 0]
# Second queue: [29, 25, 21, 17, 13, 9, 5, 1]
# Best effort queue: [20, 14, 13, 10, 9, 6, 4, 3, 2, 0]
# ----------
# current step = 37
# -----
# Average delay of first queue: 15.0
# Average delay of second queue: 15.0
# Average delay of best-effort queue: 8.1
# -----
# Packets removed from first queue: 11
# Packets removed from second queue: 11
# Packets removed from best-effort queue: 15
# ----------
# First queue: [31, 28, 24, 21, 18, 14, 11, 8, 4, 1]
# Second queue: [30, 26, 22, 18, 14, 10, 6, 2]
# Best effort queue: [15, 14, 11, 10, 7, 5, 4, 3, 1, 0]
# ----------
# current step = 38
# -----
# Average delay of first queue: 16.0
# Average delay of second queue: 16.0
# Average delay of best-effort queue: 7.0
# -----
# Packets removed from first queue: 11
# Packets removed from second queue: 11
# Packets removed from best-effort queue: 16
# ----------
# First queue: [29, 25, 22, 19, 15, 12, 9, 5, 2]
# Second queue: [31, 27, 23, 19, 15, 11, 7, 3]
# Best effort queue: [16, 15, 12, 11, 8, 6, 5, 4, 2, 1]
# ----------
# current step = 39
# -----
# Average delay of first queue: 15.333333333333334
# Average delay of second queue: 17.0
# Average delay of best-effort queue: 8.0
# -----
# Packets removed from first queue: 12
# Packets removed from second queue: 11
# Packets removed from best-effort queue: 16
# ----------
# First queue: [30, 26, 23, 20, 16, 13, 10, 6, 3, 0]
# Second queue: [28, 24, 20, 16, 12, 8, 4, 0]
# Best effort queue: [17, 16, 13, 12, 9, 7, 6, 5, 3, 2]
# ----------
# current step = 40
# -----
# Average delay of first queue: 14.7
# Average delay of second queue: 14.0
# Average delay of best-effort queue: 9.0
# -----
# Packets removed from first queue: 12
# Packets removed from second queue: 12
# Packets removed from best-effort queue: 16
# ----------
# First queue: [31, 27, 24, 21, 17, 14, 11, 7, 4, 1]
# Second queue: [25, 21, 17, 13, 9, 5, 1]
# Best effort queue: [18, 17, 14, 13, 10, 8, 7, 6, 4, 3]
# ----------
# current step = 41
# -----
# Average delay of first queue: 15.7
# Average delay of second queue: 13.0
# Average delay of best-effort queue: 10.0
# -----
# Packets removed from first queue: 12
# Packets removed from second queue: 13
# Packets removed from best-effort queue: 16
# ----------
# First queue: [32, 28, 25, 22, 18, 15, 12, 8, 5, 2]
# Second queue: [26, 22, 18, 14, 10, 6, 2]
# Best effort queue: [18, 15, 14, 11, 9, 8, 7, 5, 4, 0]
# ----------
# current step = 42
# -----
# Average delay of first queue: 16.7
# Average delay of second queue: 14.0
# Average delay of best-effort queue: 9.1
# -----
# Packets removed from first queue: 12
# Packets removed from second queue: 13
# Packets removed from best-effort queue: 17
# ----------
# First queue: [33, 29, 26, 23, 19, 16, 13, 9, 6, 3]
# Second queue: [23, 19, 15, 11, 7, 3]
# Best effort queue: [19, 16, 15, 12, 10, 9, 8, 6, 5, 1]
# ----------
# current step = 43
# -----
# Average delay of first queue: 17.7
# Average delay of second queue: 13.0
# Average delay of best-effort queue: 10.1
# -----
# Packets removed from first queue: 12
# Packets removed from second queue: 14
# Packets removed from best-effort queue: 17
# ----------
# First queue: [34, 30, 27, 24, 20, 17, 14, 10, 7, 4]
# Second queue: [24, 20, 16, 12, 8, 4, 0]
# Best effort queue: [17, 16, 13, 11, 10, 9, 7, 6, 2, 0]
# ----------
# current step = 44
# -----
# Average delay of first queue: 18.7
# Average delay of second queue: 12.0
# Average delay of best-effort queue: 9.1
# -----
# Packets removed from first queue: 12
# Packets removed from second queue: 14
# Packets removed from best-effort queue: 18
# ----------
# First queue: [35, 31, 28, 25, 21, 18, 15, 11, 8, 5]
# Second queue: [21, 17, 13, 9, 5, 1]
# Best effort queue: [18, 17, 14, 12, 11, 10, 8, 7, 3, 1]
# ----------
# current step = 45
# -----
# Average delay of first queue: 19.7
# Average delay of second queue: 11.0
# Average delay of best-effort queue: 10.1
# -----
# Packets removed from first queue: 12
# Packets removed from second queue: 15
# Packets removed from best-effort queue: 18
# ----------
# First queue: [36, 32, 29, 26, 22, 19, 16, 12, 9, 6]
# Second queue: [22, 18, 14, 10, 6, 2]
# Best effort queue: [18, 15, 13, 12, 11, 9, 8, 4, 2, 0]
# ----------
# current step = 46
# -----
# Average delay of first queue: 20.7
# Average delay of second queue: 12.0
# Average delay of best-effort queue: 9.2
# -----
# Packets removed from first queue: 12
# Packets removed from second queue: 15
# Packets removed from best-effort queue: 19
# ----------
# First queue: [33, 30, 27, 23, 20, 17, 13, 10, 7, 0]
# Second queue: [23, 19, 15, 11, 7, 3]
# Best effort queue: [19, 16, 14, 13, 12, 10, 9, 5, 3, 1]
# ----------
# current step = 47
# -----
# Average delay of first queue: 18.0
# Average delay of second queue: 13.0
# Average delay of best-effort queue: 10.2
# -----
# Packets removed from first queue: 13
# Packets removed from second queue: 15
# Packets removed from best-effort queue: 19
# ----------
# First queue: [34, 31, 28, 24, 21, 18, 14, 11, 8, 1]
# Second queue: [20, 16, 12, 8, 4, 0]
# Best effort queue: [20, 17, 15, 14, 13, 11, 10, 6, 4, 2]
# ----------
# current step = 48
# -----
# Average delay of first queue: 19.0
# Average delay of second queue: 10.0
# Average delay of best-effort queue: 11.2
# -----
# Packets removed from first queue: 13
# Packets removed from second queue: 16
# Packets removed from best-effort queue: 19
# ----------
# First queue: [32, 29, 25, 22, 19, 15, 12, 9, 2, 0]
# Second queue: [21, 17, 13, 9, 5, 1]
# Best effort queue: [21, 18, 16, 15, 14, 12, 11, 7, 5, 3]
# ----------
# current step = 49
# -----
# Average delay of first queue: 16.5
# Average delay of second queue: 11.0
# Average delay of best-effort queue: 12.2
# -----
# Packets removed from first queue: 14
# Packets removed from second queue: 16
# Packets removed from best-effort queue: 19
# ----------
# First queue: [33, 30, 26, 23, 20, 16, 13, 10, 3, 1]
# Second queue: [22, 18, 14, 10, 6, 2]
# Best effort queue: [19, 17, 16, 15, 13, 12, 8, 6, 4, 0]
# ----------
# current step = 50
# -----
# Average delay of first queue: 17.5
# Average delay of second queue: 12.0
# Average delay of best-effort queue: 11.0
# -----
# Packets removed from first queue: 14
# Packets removed from second queue: 16
# Packets removed from best-effort queue: 20
# -24

# %%
random_scheduler(2)
# Out:
# ----------
# First queue: [1, 1, 1, 3, 2, 6, 6, 3, 3, 5]
# Second queue: [5, 1, 5, 6, 2, 4, 6, 4, 6]
# Best effort queue: [5, 3, 5, 4, 5, 3, 1, 1, 3, 4]
# ----------
# current step = 1
# -----
# Average delay of first queue: 3.1
# Average delay of second queue: 4.333333333333333
# Average delay of best-effort queue: 3.4
# -----
# Packets removed from first queue: 0
# Packets removed from second queue: 1
# Packets removed from best-effort queue: 0
# ----------
# First queue: [2, 2, 2, 4, 3, 7, 7, 4, 4, 6]
# Second queue: [2, 6, 7, 3, 5, 7, 5, 7, 0]
# Best effort queue: [6, 4, 6, 5, 6, 4, 2, 2, 4, 5]
# ----------
# current step = 2
# -----
# Average delay of first queue: 4.1
# Average delay of second queue: 4.666666666666667
# Average delay of best-effort queue: 4.4
# -----
# Packets removed from first queue: 0
# Packets removed from second queue: 2
# Packets removed from best-effort queue: 0
# ----------
# First queue: [3, 3, 3, 5, 4, 8, 8, 5, 5, 7]
# Second queue: [7, 8, 4, 6, 8, 6, 8, 1]
# Best effort queue: [7, 5, 7, 6, 7, 5, 3, 3, 5, 6]
# ----------
# current step = 3
# -----
# Average delay of first queue: 5.1
# Average delay of second queue: 6.0
# Average delay of best-effort queue: 5.4
# -----
# Packets removed from first queue: 0
# Packets removed from second queue: 3
# Packets removed from best-effort queue: 0
# ----------
# First queue: [4, 4, 4, 6, 5, 9, 9, 6, 6, 8]
# Second queue: [8, 9, 5, 7, 9, 7, 9, 2]
# Best effort queue: [6, 8, 7, 8, 6, 4, 4, 6, 7, 0]
# ----------
# current step = 4
# -----
# Average delay of first queue: 6.1
# Average delay of second queue: 7.0
# Average delay of best-effort queue: 5.6
# -----
# Packets removed from first queue: 0
# Packets removed from second queue: 3
# Packets removed from best-effort queue: 1
# ----------
# First queue: [5, 5, 7, 6, 10, 10, 7, 7, 9, 0]
# Second queue: [9, 10, 6, 8, 10, 8, 10, 3]
# Best effort queue: [7, 9, 8, 9, 7, 5, 5, 7, 8, 1]
# ----------
# current step = 5
# -----
# Average delay of first queue: 6.6
# Average delay of second queue: 8.0
# Average delay of best-effort queue: 6.6
# -----
# Packets removed from first queue: 1
# Packets removed from second queue: 3
# Packets removed from best-effort queue: 1
# ----------
# First queue: [6, 6, 8, 7, 11, 11, 8, 8, 10, 1]
# Second queue: [10, 11, 7, 9, 11, 9, 11, 4, 0]
# Best effort queue: [10, 9, 10, 8, 6, 6, 8, 9, 2, 0]
# ----------
# current step = 6
# -----
# Average delay of first queue: 7.6
# Average delay of second queue: 8.0
# Average delay of best-effort queue: 6.8
# -----
# Packets removed from first queue: 1
# Packets removed from second queue: 3
# Packets removed from best-effort queue: 2
# ----------
# First queue: [7, 9, 8, 12, 12, 9, 9, 11, 2, 0]
# Second queue: [11, 12, 8, 10, 12, 10, 12, 5, 1]
# Best effort queue: [11, 10, 11, 9, 7, 7, 9, 10, 3, 1]
# ----------
# current step = 7
# -----
# Average delay of first queue: 7.9
# Average delay of second queue: 9.0
# Average delay of best-effort queue: 7.8
# -----
# Packets removed from first queue: 2
# Packets removed from second queue: 3
# Packets removed from best-effort queue: 2
# ----------
# First queue: [10, 9, 13, 13, 10, 10, 12, 3, 1, 0]
# Second queue: [12, 13, 9, 11, 13, 11, 13, 6, 2]
# Best effort queue: [12, 11, 12, 10, 8, 8, 10, 11, 4, 2]
# ----------
# current step = 8
# -----
# Average delay of first queue: 8.1
# Average delay of second queue: 10.0
# Average delay of best-effort queue: 8.8
# -----
# Packets removed from first queue: 3
# Packets removed from second queue: 3
# Packets removed from best-effort queue: 2
# ----------
# First queue: [10, 14, 14, 11, 11, 13, 4, 2, 1]
# Second queue: [13, 14, 10, 12, 14, 12, 14, 7, 3]
# Best effort queue: [13, 12, 13, 11, 9, 9, 11, 12, 5, 3]
# ----------
# current step = 9
# -----
# Average delay of first queue: 8.88888888888889
# Average delay of second queue: 11.0
# Average delay of best-effort queue: 9.8
# -----
# Packets removed from first queue: 4
# Packets removed from second queue: 3
# Packets removed from best-effort queue: 2
# ----------
# First queue: [15, 15, 12, 12, 14, 5, 3, 2, 0]
# Second queue: [14, 15, 11, 13, 15, 13, 15, 8, 4, 0]
# Best effort queue: [14, 13, 14, 12, 10, 10, 12, 13, 6, 4]
# ----------
# current step = 10
# -----
# Average delay of first queue: 8.666666666666666
# Average delay of second queue: 10.8
# Average delay of best-effort queue: 10.8
# -----
# Packets removed from first queue: 5
# Packets removed from second queue: 3
# Packets removed from best-effort queue: 2
# ----------
# First queue: [16, 13, 13, 15, 6, 4, 3, 1]
# Second queue: [15, 16, 12, 14, 16, 14, 16, 9, 5, 1]
# Best effort queue: [15, 14, 15, 13, 11, 11, 13, 14, 7, 5]
# ----------
# current step = 11
# -----
# Average delay of first queue: 8.875
# Average delay of second queue: 11.8
# Average delay of best-effort queue: 11.8
# -----
# Packets removed from first queue: 6
# Packets removed from second queue: 3
# Packets removed from best-effort queue: 2
# ----------
# First queue: [17, 14, 14, 16, 7, 5, 4, 2]
# Second queue: [17, 13, 15, 17, 15, 17, 10, 6, 2]
# Best effort queue: [16, 15, 16, 14, 12, 12, 14, 15, 8, 6]
# ----------
# current step = 12
# -----
# Average delay of first queue: 9.875
# Average delay of second queue: 12.444444444444445
# Average delay of best-effort queue: 12.8
# -----
# Packets removed from first queue: 6
# Packets removed from second queue: 4
# Packets removed from best-effort queue: 2
# ----------
# First queue: [15, 15, 17, 8, 6, 5, 3]
# Second queue: [18, 14, 16, 18, 16, 18, 11, 7, 3]
# Best effort queue: [17, 16, 17, 15, 13, 13, 15, 16, 9, 7]
# ----------
# current step = 13
# -----
# Average delay of first queue: 9.857142857142858
# Average delay of second queue: 13.444444444444445
# Average delay of best-effort queue: 13.8
# -----
# Packets removed from first queue: 7
# Packets removed from second queue: 4
# Packets removed from best-effort queue: 2
# ----------
# First queue: [16, 18, 9, 7, 6, 4, 0]
# Second queue: [19, 15, 17, 19, 17, 19, 12, 8, 4, 0]
# Best effort queue: [18, 17, 18, 16, 14, 14, 16, 17, 10, 8]
# ----------
# current step = 14
# -----
# Average delay of first queue: 8.571428571428571
# Average delay of second queue: 13.0
# Average delay of best-effort queue: 14.8
# -----
# Packets removed from first queue: 8
# Packets removed from second queue: 4
# Packets removed from best-effort queue: 2
# ----------
# First queue: [17, 19, 10, 8, 7, 5, 1]
# Second queue: [20, 16, 18, 20, 18, 20, 13, 9, 5, 1]
# Best effort queue: [18, 19, 17, 15, 15, 17, 18, 11, 9, 0]
# ----------
# current step = 15
# -----
# Average delay of first queue: 9.571428571428571
# Average delay of second queue: 14.0
# Average delay of best-effort queue: 13.9
# -----
# Packets removed from first queue: 8
# Packets removed from second queue: 4
# Packets removed from best-effort queue: 3
# ----------
# First queue: [18, 20, 11, 9, 8, 6, 2]
# Second queue: [21, 17, 19, 21, 19, 21, 14, 10, 6, 2]
# Best effort queue: [20, 18, 16, 16, 18, 19, 12, 10, 1, 0]
# ----------
# current step = 16
# -----
# Average delay of first queue: 10.571428571428571
# Average delay of second queue: 15.0
# Average delay of best-effort queue: 13.0
# -----
# Packets removed from first queue: 8
# Packets removed from second queue: 4
# Packets removed from best-effort queue: 4
# ----------
# First queue: [19, 21, 12, 10, 9, 7, 3, 0]
# Second queue: [18, 20, 22, 20, 22, 15, 11, 7, 3]
# Best effort queue: [21, 19, 17, 17, 19, 20, 13, 11, 2, 1]
# ----------
# current step = 17
# -----
# Average delay of first queue: 10.125
# Average delay of second queue: 15.333333333333334
# Average delay of best-effort queue: 14.0
# -----
# Packets removed from first queue: 8
# Packets removed from second queue: 5
# Packets removed from best-effort queue: 4
# ----------
# First queue: [20, 22, 13, 11, 10, 8, 4, 1]
# Second queue: [19, 21, 23, 21, 23, 16, 12, 8, 4, 0]
# Best effort queue: [20, 18, 18, 20, 21, 14, 12, 3, 2, 0]
# ----------
# current step = 18
# -----
# Average delay of first queue: 11.125
# Average delay of second queue: 14.7
# Average delay of best-effort queue: 12.8
# -----
# Packets removed from first queue: 8
# Packets removed from second queue: 5
# Packets removed from best-effort queue: 5
# ----------
# First queue: [21, 23, 14, 12, 11, 9, 5, 2]
# Second queue: [20, 22, 24, 22, 24, 17, 13, 9, 5, 1]
# Best effort queue: [19, 19, 21, 22, 15, 13, 4, 3, 1, 0]
# ----------
# current step = 19
# -----
# Average delay of first queue: 12.125
# Average delay of second queue: 15.7
# Average delay of best-effort queue: 11.7
# -----
# Packets removed from first queue: 8
# Packets removed from second queue: 5
# Packets removed from best-effort queue: 6
# ----------
# First queue: [22, 24, 15, 13, 12, 10, 6, 3, 0]
# Second queue: [21, 23, 25, 23, 25, 18, 14, 10, 6, 2]
# Best effort queue: [20, 22, 23, 16, 14, 5, 4, 2, 1, 0]
# ----------
# current step = 20
# -----
# Average delay of first queue: 11.666666666666666
# Average delay of second queue: 16.7
# Average delay of best-effort queue: 10.7
# -----
# Packets removed from first queue: 8
# Packets removed from second queue: 5
# Packets removed from best-effort queue: 7
# ----------
# First queue: [25, 16, 14, 13, 11, 7, 4, 1]
# Second queue: [22, 24, 26, 24, 26, 19, 15, 11, 7, 3]
# Best effort queue: [21, 23, 24, 17, 15, 6, 5, 3, 2, 1]
# ----------
# current step = 21
# -----
# Average delay of first queue: 11.375
# Average delay of second queue: 17.7
# Average delay of best-effort queue: 11.7
# -----
# Packets removed from first queue: 9
# Packets removed from second queue: 5
# Packets removed from best-effort queue: 7
# ----------
# First queue: [26, 17, 15, 14, 12, 8, 5, 2]
# Second queue: [25, 27, 25, 27, 20, 16, 12, 8, 4, 0]
# Best effort queue: [22, 24, 25, 18, 16, 7, 6, 4, 3, 2]
# ----------
# current step = 22
# -----
# Average delay of first queue: 12.375
# Average delay of second queue: 16.4
# Average delay of best-effort queue: 12.7
# -----
# Packets removed from first queue: 9
# Packets removed from second queue: 6
# Packets removed from best-effort queue: 7
# ----------
# First queue: [27, 18, 16, 15, 13, 9, 6, 3]
# Second queue: [28, 26, 28, 21, 17, 13, 9, 5, 1]
# Best effort queue: [23, 25, 26, 19, 17, 8, 7, 5, 4, 3]
# ----------
# current step = 23
# -----
# Average delay of first queue: 13.375
# Average delay of second queue: 16.444444444444443
# Average delay of best-effort queue: 13.7
# -----
# Packets removed from first queue: 9
# Packets removed from second queue: 7
# Packets removed from best-effort queue: 7
# ----------
# First queue: [28, 19, 17, 16, 14, 10, 7, 4, 0]
# Second queue: [29, 27, 29, 22, 18, 14, 10, 6, 2]
# Best effort queue: [26, 27, 20, 18, 9, 8, 6, 5, 4, 0]
# ----------
# current step = 24
# -----
# Average delay of first queue: 12.777777777777779
# Average delay of second queue: 17.444444444444443
# Average delay of best-effort queue: 12.3
# -----
# Packets removed from first queue: 9
# Packets removed from second queue: 7
# Packets removed from best-effort queue: 8
# ----------
# First queue: [29, 20, 18, 17, 15, 11, 8, 5, 1]
# Second queue: [30, 28, 30, 23, 19, 15, 11, 7, 3]
# Best effort queue: [28, 21, 19, 10, 9, 7, 6, 5, 1, 0]
# ----------
# current step = 25
# -----
# Average delay of first queue: 13.777777777777779
# Average delay of second queue: 18.444444444444443
# Average delay of best-effort queue: 10.6
# -----
# Packets removed from first queue: 9
# Packets removed from second queue: 7
# Packets removed from best-effort queue: 9
# ----------
# First queue: [30, 21, 19, 18, 16, 12, 9, 6, 2]
# Second queue: [29, 31, 24, 20, 16, 12, 8, 4, 0]
# Best effort queue: [29, 22, 20, 11, 10, 8, 7, 6, 2, 1]
# ----------
# current step = 26
# -----
# Average delay of first queue: 14.777777777777779
# Average delay of second queue: 16.0
# Average delay of best-effort queue: 11.6
# -----
# Packets removed from first queue: 9
# Packets removed from second queue: 8
# Packets removed from best-effort queue: 9
# ----------
# First queue: [31, 22, 20, 19, 17, 13, 10, 7, 3, 0]
# Second queue: [30, 32, 25, 21, 17, 13, 9, 5, 1]
# Best effort queue: [23, 21, 12, 11, 9, 8, 7, 3, 2, 0]
# ----------
# current step = 27
# -----
# Average delay of first queue: 14.2
# Average delay of second queue: 17.0
# Average delay of best-effort queue: 9.6
# -----
# Packets removed from first queue: 9
# Packets removed from second queue: 8
# Packets removed from best-effort queue: 10
# ----------
# First queue: [32, 23, 21, 20, 18, 14, 11, 8, 4, 1]
# Second queue: [33, 26, 22, 18, 14, 10, 6, 2]
# Best effort queue: [24, 22, 13, 12, 10, 9, 8, 4, 3, 1]
# ----------
# current step = 28
# -----
# Average delay of first queue: 15.2
# Average delay of second queue: 16.375
# Average delay of best-effort queue: 10.6
# -----
# Packets removed from first queue: 9
# Packets removed from second queue: 9
# Packets removed from best-effort queue: 10
# ----------
# First queue: [33, 24, 22, 21, 19, 15, 12, 9, 5, 2]
# Second queue: [27, 23, 19, 15, 11, 7, 3]
# Best effort queue: [25, 23, 14, 13, 11, 10, 9, 5, 4, 2]
# ----------
# current step = 29
# -----
# Average delay of first queue: 16.2
# Average delay of second queue: 15.0
# Average delay of best-effort queue: 11.6
# -----
# Packets removed from first queue: 9
# Packets removed from second queue: 10
# Packets removed from best-effort queue: 10
# ----------
# First queue: [34, 25, 23, 22, 20, 16, 13, 10, 6, 3]
# Second queue: [24, 20, 16, 12, 8, 4, 0]
# Best effort queue: [26, 24, 15, 14, 12, 11, 10, 6, 5, 3]
# ----------
# current step = 30
# -----
# Average delay of first queue: 17.2
# Average delay of second queue: 12.0
# Average delay of best-effort queue: 12.6
# -----
# Packets removed from first queue: 9
# Packets removed from second queue: 11
# Packets removed from best-effort queue: 10
# ----------
# First queue: [26, 24, 23, 21, 17, 14, 11, 7, 4, 0]
# Second queue: [25, 21, 17, 13, 9, 5, 1]
# Best effort queue: [27, 25, 16, 15, 13, 12, 11, 7, 6, 4]
# ----------
# current step = 31
# -----
# Average delay of first queue: 14.7
# Average delay of second queue: 13.0
# Average delay of best-effort queue: 13.6
# -----
# Packets removed from first queue: 10
# Packets removed from second queue: 11
# Packets removed from best-effort queue: 10
# ----------
# First queue: [27, 25, 24, 22, 18, 15, 12, 8, 5, 1]
# Second queue: [22, 18, 14, 10, 6, 2]
# Best effort queue: [28, 26, 17, 16, 14, 13, 12, 8, 7, 5]
# ----------
# current step = 32
# -----
# Average delay of first queue: 15.7
# Average delay of second queue: 12.0
# Average delay of best-effort queue: 14.6
# -----
# Packets removed from first queue: 10
# Packets removed from second queue: 12
# Packets removed from best-effort queue: 10
# ----------
# First queue: [28, 26, 25, 23, 19, 16, 13, 9, 6, 2]
# Second queue: [23, 19, 15, 11, 7, 3]
# Best effort queue: [27, 18, 17, 15, 14, 13, 9, 8, 6, 0]
# ----------
# current step = 33
# -----
# Average delay of first queue: 16.7
# Average delay of second queue: 13.0
# Average delay of best-effort queue: 12.7
# -----
# Packets removed from first queue: 10
# Packets removed from second queue: 12
# Packets removed from best-effort queue: 11
# ----------
# First queue: [29, 27, 26, 24, 20, 17, 14, 10, 7, 3]
# Second queue: [24, 20, 16, 12, 8, 4, 0]
# Best effort queue: [19, 18, 16, 15, 14, 10, 9, 7, 1, 0]
# ----------
# current step = 34
# -----
# Average delay of first queue: 17.7
# Average delay of second queue: 12.0
# Average delay of best-effort queue: 10.9
# -----
# Packets removed from first queue: 10
# Packets removed from second queue: 12
# Packets removed from best-effort queue: 12
# ----------
# First queue: [30, 28, 27, 25, 21, 18, 15, 11, 8, 4]
# Second queue: [21, 17, 13, 9, 5, 1]
# Best effort queue: [20, 19, 17, 16, 15, 11, 10, 8, 2, 1]
# ----------
# current step = 35
# -----
# Average delay of first queue: 18.7
# Average delay of second queue: 11.0
# Average delay of best-effort queue: 11.9
# -----
# Packets removed from first queue: 10
# Packets removed from second queue: 13
# Packets removed from best-effort queue: 12
# ----------
# First queue: [31, 29, 28, 26, 22, 19, 16, 12, 9, 5]
# Second queue: [22, 18, 14, 10, 6, 2]
# Best effort queue: [20, 18, 17, 16, 12, 11, 9, 3, 2, 0]
# ----------
# current step = 36
# -----
# Average delay of first queue: 19.7
# Average delay of second queue: 12.0
# Average delay of best-effort queue: 10.8
# -----
# Packets removed from first queue: 10
# Packets removed from second queue: 13
# Packets removed from best-effort queue: 13
# ----------
# First queue: [32, 30, 29, 27, 23, 20, 17, 13, 10, 6]
# Second queue: [23, 19, 15, 11, 7, 3]
# Best effort queue: [19, 18, 17, 13, 12, 10, 4, 3, 1, 0]
# ----------
# current step = 37
# -----
# Average delay of first queue: 20.7
# Average delay of second queue: 13.0
# Average delay of best-effort queue: 9.7
# -----
# Packets removed from first queue: 10
# Packets removed from second queue: 13
# Packets removed from best-effort queue: 14
# ----------
# First queue: [31, 30, 28, 24, 21, 18, 14, 11, 7, 0]
# Second queue: [24, 20, 16, 12, 8, 4, 0]
# Best effort queue: [20, 19, 18, 14, 13, 11, 5, 4, 2, 1]
# ----------
# current step = 38
# -----
# Average delay of first queue: 18.4
# Average delay of second queue: 12.0
# Average delay of best-effort queue: 10.7
# -----
# Packets removed from first queue: 11
# Packets removed from second queue: 13
# Packets removed from best-effort queue: 14
# ----------
# First queue: [32, 31, 29, 25, 22, 19, 15, 12, 8, 1]
# Second queue: [21, 17, 13, 9, 5, 1]
# Best effort queue: [21, 20, 19, 15, 14, 12, 6, 5, 3, 2]
# ----------
# current step = 39
# -----
# Average delay of first queue: 19.4
# Average delay of second queue: 11.0
# Average delay of best-effort queue: 11.7
# -----
# Packets removed from first queue: 11
# Packets removed from second queue: 14
# Packets removed from best-effort queue: 14
# ----------
# First queue: [33, 32, 30, 26, 23, 20, 16, 13, 9, 2]
# Second queue: [18, 14, 10, 6, 2]
# Best effort queue: [22, 21, 20, 16, 15, 13, 7, 6, 4, 3]
# ----------
# current step = 40
# -----
# Average delay of first queue: 20.4
# Average delay of second queue: 10.0
# Average delay of best-effort queue: 12.7
# -----
# Packets removed from first queue: 11
# Packets removed from second queue: 15
# Packets removed from best-effort queue: 14
# ----------
# First queue: [34, 33, 31, 27, 24, 21, 17, 14, 10, 3]
# Second queue: [15, 11, 7, 3]
# Best effort queue: [23, 22, 21, 17, 16, 14, 8, 7, 5, 4]
# ----------
# current step = 41
# -----
# Average delay of first queue: 21.4
# Average delay of second queue: 9.0
# Average delay of best-effort queue: 13.7
# -----
# Packets removed from first queue: 11
# Packets removed from second queue: 16
# Packets removed from best-effort queue: 14
# ----------
# First queue: [35, 34, 32, 28, 25, 22, 18, 15, 11, 4]
# Second queue: [16, 12, 8, 4, 0]
# Best effort queue: [23, 22, 18, 17, 15, 9, 8, 6, 5, 0]
# ----------
# current step = 42
# -----
# Average delay of first queue: 22.4
# Average delay of second queue: 8.0
# Average delay of best-effort queue: 12.3
# -----
# Packets removed from first queue: 11
# Packets removed from second queue: 16
# Packets removed from best-effort queue: 15
# ----------
# First queue: [36, 35, 33, 29, 26, 23, 19, 16, 12, 5]
# Second queue: [17, 13, 9, 5, 1]
# Best effort queue: [23, 19, 18, 16, 10, 9, 7, 6, 1, 0]
# ----------
# current step = 43
# -----
# Average delay of first queue: 23.4
# Average delay of second queue: 9.0
# Average delay of best-effort queue: 10.9
# -----
# Packets removed from first queue: 11
# Packets removed from second queue: 16
# Packets removed from best-effort queue: 16
# ----------
# First queue: [37, 36, 34, 30, 27, 24, 20, 17, 13, 6]
# Second queue: [14, 10, 6, 2]
# Best effort queue: [24, 20, 19, 17, 11, 10, 8, 7, 2, 1]
# ----------
# current step = 44
# -----
# Average delay of first queue: 24.4
# Average delay of second queue: 8.0
# Average delay of best-effort queue: 11.9
# -----
# Packets removed from first queue: 11
# Packets removed from second queue: 17
# Packets removed from best-effort queue: 16
# ----------
# First queue: [38, 37, 35, 31, 28, 25, 21, 18, 14, 7]
# Second queue: [15, 11, 7, 3]
# Best effort queue: [21, 20, 18, 12, 11, 9, 8, 3, 2, 0]
# ----------
# current step = 45
# -----
# Average delay of first queue: 25.4
# Average delay of second queue: 9.0
# Average delay of best-effort queue: 10.4
# -----
# Packets removed from first queue: 11
# Packets removed from second queue: 17
# Packets removed from best-effort queue: 17
# ----------
# First queue: [39, 38, 36, 32, 29, 26, 22, 19, 15, 8]
# Second queue: [12, 8, 4, 0]
# Best effort queue: [22, 21, 19, 13, 12, 10, 9, 4, 3, 1]
# ----------
# current step = 46
# -----
# Average delay of first queue: 26.4
# Average delay of second queue: 6.0
# Average delay of best-effort queue: 11.4
# -----
# Packets removed from first queue: 11
# Packets removed from second queue: 18
# Packets removed from best-effort queue: 17
# ----------
# First queue: [40, 39, 37, 33, 30, 27, 23, 20, 16, 9]
# Second queue: [9, 5, 1]
# Best effort queue: [23, 22, 20, 14, 13, 11, 10, 5, 4, 2]
# ----------
# current step = 47
# -----
# Average delay of first queue: 27.4
# Average delay of second queue: 5.0
# Average delay of best-effort queue: 12.4
# -----
# Packets removed from first queue: 11
# Packets removed from second queue: 19
# Packets removed from best-effort queue: 17
# ----------
# First queue: [41, 40, 38, 34, 31, 28, 24, 21, 17, 10]
# Second queue: [6, 2]
# Best effort queue: [24, 23, 21, 15, 14, 12, 11, 6, 5, 3]
# ----------
# current step = 48
# -----
# Average delay of first queue: 28.4
# Average delay of second queue: 4.0
# Average delay of best-effort queue: 13.4
# -----
# Packets removed from first queue: 11
# Packets removed from second queue: 20
# Packets removed from best-effort queue: 17
# ----------
# First queue: [42, 41, 39, 35, 32, 29, 25, 22, 18, 11]
# Second queue: [7, 3]
# Best effort queue: [24, 22, 16, 15, 13, 12, 7, 6, 4, 0]
# ----------
# current step = 49
# -----
# Average delay of first queue: 29.4
# Average delay of second queue: 5.0
# Average delay of best-effort queue: 11.9
# -----
# Packets removed from first queue: 11
# Packets removed from second queue: 20
# Packets removed from best-effort queue: 18
# ----------
# First queue: [43, 42, 40, 36, 33, 30, 26, 23, 19, 12]
# Second queue: [8, 4, 0]
# Best effort queue: [23, 17, 16, 14, 13, 8, 7, 5, 1, 0]
# ----------
# current step = 50
# -----
# Average delay of first queue: 30.4
# Average delay of second queue: 4.0
# Average delay of best-effort queue: 10.4
# -----
# Packets removed from first queue: 11
# Packets removed from second queue: 20
# Packets removed from best-effort queue: 19
# -25

# %%
def is_empty(queue):
    if (queue == []):
        return True
    else:
        return False

# %%
# FIFO
def fifo_action(obs):
    first_queue = obs["queues"][0]
    second_queue = obs["queues"][1]
    best_effort_queue = obs["queues"][2]
    
    first_queue_element = None
    second_queue_element = None
    best_effort_queue_element = None
    
    if (not is_empty(first_queue)):
        first_queue_element = first_queue[0]
    
    if (not is_empty(second_queue_element)):
        second_queue_element = second_queue[0]
    
    if (not is_empty(best_effort_queue)):
        best_effort_queue_element = best_effort_queue[0]
    
    largest_delay = max(first_queue_element, second_queue_element, best_effort_queue_element)
    
    action = 0
    if (largest_delay == best_effort_queue_element):
        action = 2
    elif (largest_delay == second_queue_element):
        action = 1
    
    return action

# %%
def fifo_scheduler(seed = None):
    terminated = False 
    truncated = False
    obs, info = env.reset(seed)
    score = 0
    while not terminated: 

    #     fifo
        action = fifo_action(obs)
        obs, reward, terminated, truncated, info = env.step(action)
        score += reward
        print_observation(obs)
        print_info(info)
    print(score)

# %%
fifo_scheduler(0)
# Out:
# ----------
# First queue: [4, 4, 1, 3, 5, 4, 4, 3, 4, 3]
# Second queue: [5, 2, 5, 2, 3, 2, 1, 5, 3, 5]
# Best effort queue: [5, 2, 3, 1, 6, 1, 6, 3, 4, 0]
# ----------
# current step = 1
# -----
# Average delay of first queue: 3.5
# Average delay of second queue: 3.3
# Average delay of best-effort queue: 3.1
# -----
# Packets removed from first queue: 0
# Packets removed from second queue: 0
# Packets removed from best-effort queue: 1
# ----------
# First queue: [5, 5, 2, 4, 6, 5, 5, 4, 5, 4]
# Second queue: [6, 3, 6, 3, 4, 3, 2, 6, 4, 6]
# Best effort queue: [3, 4, 2, 7, 2, 7, 4, 5, 1, 0]
# ----------
# current step = 2
# -----
# Average delay of first queue: 4.5
# Average delay of second queue: 4.3
# Average delay of best-effort queue: 3.5
# -----
# Packets removed from first queue: 0
# Packets removed from second queue: 0
# Packets removed from best-effort queue: 2
# ----------
# First queue: [6, 6, 3, 5, 7, 6, 6, 5, 6, 5]
# Second queue: [4, 7, 4, 5, 4, 3, 7, 5, 7]
# Best effort queue: [4, 5, 3, 8, 3, 8, 5, 6, 2, 1]
# ----------
# current step = 3
# -----
# Average delay of first queue: 5.5
# Average delay of second queue: 5.111111111111111
# Average delay of best-effort queue: 4.5
# -----
# Packets removed from first queue: 0
# Packets removed from second queue: 1
# Packets removed from best-effort queue: 2
# ----------
# First queue: [7, 4, 6, 8, 7, 7, 6, 7, 6, 0]
# Second queue: [5, 8, 5, 6, 5, 4, 8, 6, 8, 0]
# Best effort queue: [5, 6, 4, 9, 4, 9, 6, 7, 3, 2]
# ----------
# current step = 4
# -----
# Average delay of first queue: 5.8
# Average delay of second queue: 5.5
# Average delay of best-effort queue: 5.5
# -----
# Packets removed from first queue: 1
# Packets removed from second queue: 1
# Packets removed from best-effort queue: 2
# ----------
# First queue: [5, 7, 9, 8, 8, 7, 8, 7, 1, 0]
# Second queue: [6, 9, 6, 7, 6, 5, 9, 7, 9, 1]
# Best effort queue: [6, 7, 5, 10, 5, 10, 7, 8, 4, 3]
# ----------
# current step = 5
# -----
# Average delay of first queue: 6.0
# Average delay of second queue: 6.5
# Average delay of best-effort queue: 6.5
# -----
# Packets removed from first queue: 2
# Packets removed from second queue: 1
# Packets removed from best-effort queue: 2
# ----------
# First queue: [6, 8, 10, 9, 9, 8, 9, 8, 2, 1]
# Second queue: [7, 10, 7, 8, 7, 6, 10, 8, 10, 2]
# Best effort queue: [8, 6, 11, 6, 11, 8, 9, 5, 4, 0]
# ----------
# current step = 6
# -----
# Average delay of first queue: 7.0
# Average delay of second queue: 7.5
# Average delay of best-effort queue: 6.8
# -----
# Packets removed from first queue: 2
# Packets removed from second queue: 1
# Packets removed from best-effort queue: 3
# ----------
# First queue: [7, 9, 11, 10, 10, 9, 10, 9, 3, 2]
# Second queue: [8, 11, 8, 9, 8, 7, 11, 9, 11, 3]
# Best effort queue: [7, 12, 7, 12, 9, 10, 6, 5, 1, 0]
# ----------
# current step = 7
# -----
# Average delay of first queue: 8.0
# Average delay of second queue: 8.5
# Average delay of best-effort queue: 6.9
# -----
# Packets removed from first queue: 2
# Packets removed from second queue: 1
# Packets removed from best-effort queue: 4
# ----------
# First queue: [8, 10, 12, 11, 11, 10, 11, 10, 4, 3]
# Second queue: [12, 9, 10, 9, 8, 12, 10, 12, 4, 0]
# Best effort queue: [8, 13, 8, 13, 10, 11, 7, 6, 2, 1]
# ----------
# current step = 8
# -----
# Average delay of first queue: 9.0
# Average delay of second queue: 8.6
# Average delay of best-effort queue: 7.9
# -----
# Packets removed from first queue: 2
# Packets removed from second queue: 2
# Packets removed from best-effort queue: 4
# ----------
# First queue: [9, 11, 13, 12, 12, 11, 12, 11, 5, 4]
# Second queue: [10, 11, 10, 9, 13, 11, 13, 5, 1]
# Best effort queue: [9, 14, 9, 14, 11, 12, 8, 7, 3, 2]
# ----------
# current step = 9
# -----
# Average delay of first queue: 10.0
# Average delay of second queue: 9.222222222222221
# Average delay of best-effort queue: 8.9
# -----
# Packets removed from first queue: 2
# Packets removed from second queue: 3
# Packets removed from best-effort queue: 4
# ----------
# First queue: [10, 12, 14, 13, 13, 12, 13, 12, 6, 5]
# Second queue: [12, 11, 10, 14, 12, 14, 6, 2]
# Best effort queue: [10, 15, 10, 15, 12, 13, 9, 8, 4, 3]
# ----------
# current step = 10
# -----
# Average delay of first queue: 11.0
# Average delay of second queue: 10.125
# Average delay of best-effort queue: 9.9
# -----
# Packets removed from first queue: 2
# Packets removed from second queue: 4
# Packets removed from best-effort queue: 4
# ----------
# First queue: [11, 13, 15, 14, 14, 13, 14, 13, 7, 6]
# Second queue: [12, 11, 15, 13, 15, 7, 3]
# Best effort queue: [11, 16, 11, 16, 13, 14, 10, 9, 5, 4]
# ----------
# current step = 11
# -----
# Average delay of first queue: 12.0
# Average delay of second queue: 10.857142857142858
# Average delay of best-effort queue: 10.9
# -----
# Packets removed from first queue: 2
# Packets removed from second queue: 5
# Packets removed from best-effort queue: 4
# ----------
# First queue: [12, 14, 16, 15, 15, 14, 15, 14, 8, 7]
# Second queue: [12, 16, 14, 16, 8, 4, 0]
# Best effort queue: [12, 17, 12, 17, 14, 15, 11, 10, 6, 5]
# ----------
# current step = 12
# -----
# Average delay of first queue: 13.0
# Average delay of second queue: 10.0
# Average delay of best-effort queue: 11.9
# -----
# Packets removed from first queue: 2
# Packets removed from second queue: 6
# Packets removed from best-effort queue: 4
# ----------
# First queue: [13, 15, 17, 16, 16, 15, 16, 15, 9, 8]
# Second queue: [13, 17, 15, 17, 9, 5, 1]
# Best effort queue: [18, 13, 18, 15, 16, 12, 11, 7, 6, 0]
# ----------
# current step = 13
# -----
# Average delay of first queue: 14.0
# Average delay of second queue: 11.0
# Average delay of best-effort queue: 11.6
# -----
# Packets removed from first queue: 2
# Packets removed from second queue: 6
# Packets removed from best-effort queue: 5
# ----------
# First queue: [14, 16, 18, 17, 17, 16, 17, 16, 10, 9]
# Second queue: [14, 18, 16, 18, 10, 6, 2]
# Best effort queue: [14, 19, 16, 17, 13, 12, 8, 7, 1, 0]
# ----------
# current step = 14
# -----
# Average delay of first queue: 15.0
# Average delay of second queue: 12.0
# Average delay of best-effort queue: 10.7
# -----
# Packets removed from first queue: 2
# Packets removed from second queue: 6
# Packets removed from best-effort queue: 6
# ----------
# First queue: [15, 17, 19, 18, 18, 17, 18, 17, 11, 10]
# Second queue: [15, 19, 17, 19, 11, 7, 3]
# Best effort queue: [20, 17, 18, 14, 13, 9, 8, 2, 1, 0]
# ----------
# current step = 15
# -----
# Average delay of first queue: 16.0
# Average delay of second queue: 13.0
# Average delay of best-effort queue: 10.2
# -----
# Packets removed from first queue: 2
# Packets removed from second queue: 6
# Packets removed from best-effort queue: 7
# ----------
# First queue: [16, 18, 20, 19, 19, 18, 19, 18, 12, 11]
# Second queue: [16, 20, 18, 20, 12, 8, 4, 0]
# Best effort queue: [18, 19, 15, 14, 10, 9, 3, 2, 1, 0]
# ----------
# current step = 16
# -----
# Average delay of first queue: 17.0
# Average delay of second queue: 12.25
# Average delay of best-effort queue: 9.1
# -----
# Packets removed from first queue: 2
# Packets removed from second queue: 6
# Packets removed from best-effort queue: 8
# ----------
# First queue: [17, 19, 21, 20, 20, 19, 20, 19, 13, 12]
# Second queue: [17, 21, 19, 21, 13, 9, 5, 1]
# Best effort queue: [20, 16, 15, 11, 10, 4, 3, 2, 1, 0]
# ----------
# current step = 17
# -----
# Average delay of first queue: 18.0
# Average delay of second queue: 13.25
# Average delay of best-effort queue: 8.2
# -----
# Packets removed from first queue: 2
# Packets removed from second queue: 6
# Packets removed from best-effort queue: 9
# ----------
# First queue: [18, 20, 22, 21, 21, 20, 21, 20, 14, 13]
# Second queue: [18, 22, 20, 22, 14, 10, 6, 2]
# Best effort queue: [17, 16, 12, 11, 5, 4, 3, 2, 1, 0]
# ----------
# current step = 18
# -----
# Average delay of first queue: 19.0
# Average delay of second queue: 14.25
# Average delay of best-effort queue: 7.1
# -----
# Packets removed from first queue: 2
# Packets removed from second queue: 6
# Packets removed from best-effort queue: 10
# ----------
# First queue: [19, 21, 23, 22, 22, 21, 22, 21, 15, 14]
# Second queue: [23, 21, 23, 15, 11, 7, 3]
# Best effort queue: [18, 17, 13, 12, 6, 5, 4, 3, 2, 1]
# ----------
# current step = 19
# -----
# Average delay of first queue: 20.0
# Average delay of second queue: 14.714285714285714
# Average delay of best-effort queue: 8.1
# -----
# Packets removed from first queue: 2
# Packets removed from second queue: 7
# Packets removed from best-effort queue: 10
# ----------
# First queue: [20, 22, 24, 23, 23, 22, 23, 22, 16, 15]
# Second queue: [22, 24, 16, 12, 8, 4, 0]
# Best effort queue: [19, 18, 14, 13, 7, 6, 5, 4, 3, 2]
# ----------
# current step = 20
# -----
# Average delay of first queue: 21.0
# Average delay of second queue: 12.285714285714286
# Average delay of best-effort queue: 9.1
# -----
# Packets removed from first queue: 2
# Packets removed from second queue: 8
# Packets removed from best-effort queue: 10
# ----------
# First queue: [21, 23, 25, 24, 24, 23, 24, 23, 17, 16]
# Second queue: [25, 17, 13, 9, 5, 1]
# Best effort queue: [20, 19, 15, 14, 8, 7, 6, 5, 4, 3]
# ----------
# current step = 21
# -----
# Average delay of first queue: 22.0
# Average delay of second queue: 11.666666666666666
# Average delay of best-effort queue: 10.1
# -----
# Packets removed from first queue: 2
# Packets removed from second queue: 9
# Packets removed from best-effort queue: 10
# ----------
# First queue: [22, 24, 26, 25, 25, 24, 25, 24, 18, 17]
# Second queue: [18, 14, 10, 6, 2]
# Best effort queue: [21, 20, 16, 15, 9, 8, 7, 6, 5, 4]
# ----------
# current step = 22
# -----
# Average delay of first queue: 23.0
# Average delay of second queue: 10.0
# Average delay of best-effort queue: 11.1
# -----
# Packets removed from first queue: 2
# Packets removed from second queue: 10
# Packets removed from best-effort queue: 10
# ----------
# First queue: [25, 27, 26, 26, 25, 26, 25, 19, 18, 0]
# Second queue: [19, 15, 11, 7, 3]
# Best effort queue: [22, 21, 17, 16, 10, 9, 8, 7, 6, 5]
# ----------
# current step = 23
# -----
# Average delay of first queue: 21.7
# Average delay of second queue: 11.0
# Average delay of best-effort queue: 12.1
# -----
# Packets removed from first queue: 3
# Packets removed from second queue: 10
# Packets removed from best-effort queue: 10
# ----------
# First queue: [28, 27, 27, 26, 27, 26, 20, 19, 1, 0]
# Second queue: [20, 16, 12, 8, 4, 0]
# Best effort queue: [23, 22, 18, 17, 11, 10, 9, 8, 7, 6]
# ----------
# current step = 24
# -----
# Average delay of first queue: 20.1
# Average delay of second queue: 10.0
# Average delay of best-effort queue: 13.1
# -----
# Packets removed from first queue: 4
# Packets removed from second queue: 10
# Packets removed from best-effort queue: 10
# ----------
# First queue: [28, 28, 27, 28, 27, 21, 20, 2, 1, 0]
# Second queue: [21, 17, 13, 9, 5, 1]
# Best effort queue: [24, 23, 19, 18, 12, 11, 10, 9, 8, 7]
# ----------
# current step = 25
# -----
# Average delay of first queue: 18.2
# Average delay of second queue: 11.0
# Average delay of best-effort queue: 14.1
# -----
# Packets removed from first queue: 5
# Packets removed from second queue: 10
# Packets removed from best-effort queue: 10
# ----------
# First queue: [29, 28, 29, 28, 22, 21, 3, 2, 1, 0]
# Second queue: [22, 18, 14, 10, 6, 2]
# Best effort queue: [25, 24, 20, 19, 13, 12, 11, 10, 9, 8]
# ----------
# current step = 26
# -----
# Average delay of first queue: 16.3
# Average delay of second queue: 12.0
# Average delay of best-effort queue: 15.1
# -----
# Packets removed from first queue: 6
# Packets removed from second queue: 10
# Packets removed from best-effort queue: 10
# ----------
# First queue: [29, 30, 29, 23, 22, 4, 3, 2, 1, 0]
# Second queue: [23, 19, 15, 11, 7, 3]
# Best effort queue: [26, 25, 21, 20, 14, 13, 12, 11, 10, 9]
# ----------
# current step = 27
# -----
# Average delay of first queue: 14.3
# Average delay of second queue: 13.0
# Average delay of best-effort queue: 16.1
# -----
# Packets removed from first queue: 7
# Packets removed from second queue: 10
# Packets removed from best-effort queue: 10
# ----------
# First queue: [31, 30, 24, 23, 5, 4, 3, 2, 1, 0]
# Second queue: [24, 20, 16, 12, 8, 4, 0]
# Best effort queue: [27, 26, 22, 21, 15, 14, 13, 12, 11, 10]
# ----------
# current step = 28
# -----
# Average delay of first queue: 12.3
# Average delay of second queue: 12.0
# Average delay of best-effort queue: 17.1
# -----
# Packets removed from first queue: 8
# Packets removed from second queue: 10
# Packets removed from best-effort queue: 10
# ----------
# First queue: [31, 25, 24, 6, 5, 4, 3, 2, 1, 0]
# Second queue: [25, 21, 17, 13, 9, 5, 1]
# Best effort queue: [28, 27, 23, 22, 16, 15, 14, 13, 12, 11]
# ----------
# current step = 29
# -----
# Average delay of first queue: 10.1
# Average delay of second queue: 13.0
# Average delay of best-effort queue: 18.1
# -----
# Packets removed from first queue: 9
# Packets removed from second queue: 10
# Packets removed from best-effort queue: 10
# ----------
# First queue: [26, 25, 7, 6, 5, 4, 3, 2, 1, 0]
# Second queue: [26, 22, 18, 14, 10, 6, 2]
# Best effort queue: [29, 28, 24, 23, 17, 16, 15, 14, 13, 12]
# ----------
# current step = 30
# -----
# Average delay of first queue: 7.9
# Average delay of second queue: 14.0
# Average delay of best-effort queue: 19.1
# -----
# Packets removed from first queue: 10
# Packets removed from second queue: 10
# Packets removed from best-effort queue: 10
# ----------
# First queue: [27, 26, 8, 7, 6, 5, 4, 3, 2, 1]
# Second queue: [27, 23, 19, 15, 11, 7, 3]
# Best effort queue: [29, 25, 24, 18, 17, 16, 15, 14, 13, 0]
# ----------
# current step = 31
# -----
# Average delay of first queue: 8.9
# Average delay of second queue: 15.0
# Average delay of best-effort queue: 17.1
# -----
# Packets removed from first queue: 10
# Packets removed from second queue: 10
# Packets removed from best-effort queue: 11
# ----------
# First queue: [28, 27, 9, 8, 7, 6, 5, 4, 3, 2]
# Second queue: [28, 24, 20, 16, 12, 8, 4, 0]
# Best effort queue: [26, 25, 19, 18, 17, 16, 15, 14, 1, 0]
# ----------
# current step = 32
# -----
# Average delay of first queue: 9.9
# Average delay of second queue: 14.0
# Average delay of best-effort queue: 15.1
# -----
# Packets removed from first queue: 10
# Packets removed from second queue: 10
# Packets removed from best-effort queue: 12
# ----------
# First queue: [29, 28, 10, 9, 8, 7, 6, 5, 4, 3]
# Second queue: [25, 21, 17, 13, 9, 5, 1]
# Best effort queue: [27, 26, 20, 19, 18, 17, 16, 15, 2, 1]
# ----------
# current step = 33
# -----
# Average delay of first queue: 10.9
# Average delay of second queue: 13.0
# Average delay of best-effort queue: 16.1
# -----
# Packets removed from first queue: 10
# Packets removed from second queue: 11
# Packets removed from best-effort queue: 12
# ----------
# First queue: [29, 11, 10, 9, 8, 7, 6, 5, 4, 0]
# Second queue: [26, 22, 18, 14, 10, 6, 2]
# Best effort queue: [28, 27, 21, 20, 19, 18, 17, 16, 3, 2]
# ----------
# current step = 34
# -----
# Average delay of first queue: 8.9
# Average delay of second queue: 14.0
# Average delay of best-effort queue: 17.1
# -----
# Packets removed from first queue: 11
# Packets removed from second queue: 11
# Packets removed from best-effort queue: 12
# ----------
# First queue: [12, 11, 10, 9, 8, 7, 6, 5, 1, 0]
# Second queue: [27, 23, 19, 15, 11, 7, 3]
# Best effort queue: [29, 28, 22, 21, 20, 19, 18, 17, 4, 3]
# ----------
# current step = 35
# -----
# Average delay of first queue: 6.9
# Average delay of second queue: 15.0
# Average delay of best-effort queue: 18.1
# -----
# Packets removed from first queue: 12
# Packets removed from second queue: 11
# Packets removed from best-effort queue: 12
# ----------
# First queue: [13, 12, 11, 10, 9, 8, 7, 6, 2, 1]
# Second queue: [28, 24, 20, 16, 12, 8, 4, 0]
# Best effort queue: [29, 23, 22, 21, 20, 19, 18, 5, 4, 0]
# ----------
# current step = 36
# -----
# Average delay of first queue: 7.9
# Average delay of second queue: 14.0
# Average delay of best-effort queue: 16.1
# -----
# Packets removed from first queue: 12
# Packets removed from second queue: 11
# Packets removed from best-effort queue: 13
# ----------
# First queue: [14, 13, 12, 11, 10, 9, 8, 7, 3, 2]
# Second queue: [29, 25, 21, 17, 13, 9, 5, 1]
# Best effort queue: [24, 23, 22, 21, 20, 19, 6, 5, 1, 0]
# ----------
# current step = 37
# -----
# Average delay of first queue: 8.9
# Average delay of second queue: 15.0
# Average delay of best-effort queue: 14.1
# -----
# Packets removed from first queue: 12
# Packets removed from second queue: 11
# Packets removed from best-effort queue: 14
# ----------
# First queue: [15, 14, 13, 12, 11, 10, 9, 8, 4, 3]
# Second queue: [26, 22, 18, 14, 10, 6, 2]
# Best effort queue: [25, 24, 23, 22, 21, 20, 7, 6, 2, 1]
# ----------
# current step = 38
# -----
# Average delay of first queue: 9.9
# Average delay of second queue: 14.0
# Average delay of best-effort queue: 15.1
# -----
# Packets removed from first queue: 12
# Packets removed from second queue: 12
# Packets removed from best-effort queue: 14
# ----------
# First queue: [16, 15, 14, 13, 12, 11, 10, 9, 5, 4]
# Second queue: [23, 19, 15, 11, 7, 3]
# Best effort queue: [26, 25, 24, 23, 22, 21, 8, 7, 3, 2]
# ----------
# current step = 39
# -----
# Average delay of first queue: 10.9
# Average delay of second queue: 13.0
# Average delay of best-effort queue: 16.1
# -----
# Packets removed from first queue: 12
# Packets removed from second queue: 13
# Packets removed from best-effort queue: 14
# ----------
# First queue: [17, 16, 15, 14, 13, 12, 11, 10, 6, 5]
# Second queue: [24, 20, 16, 12, 8, 4, 0]
# Best effort queue: [26, 25, 24, 23, 22, 9, 8, 4, 3, 0]
# ----------
# current step = 40
# -----
# Average delay of first queue: 11.9
# Average delay of second queue: 12.0
# Average delay of best-effort queue: 14.4
# -----
# Packets removed from first queue: 12
# Packets removed from second queue: 13
# Packets removed from best-effort queue: 15
# ----------
# First queue: [18, 17, 16, 15, 14, 13, 12, 11, 7, 6]
# Second queue: [25, 21, 17, 13, 9, 5, 1]
# Best effort queue: [26, 25, 24, 23, 10, 9, 5, 4, 1, 0]
# ----------
# current step = 41
# -----
# Average delay of first queue: 12.9
# Average delay of second queue: 13.0
# Average delay of best-effort queue: 12.7
# -----
# Packets removed from first queue: 12
# Packets removed from second queue: 13
# Packets removed from best-effort queue: 16
# ----------
# First queue: [19, 18, 17, 16, 15, 14, 13, 12, 8, 7]
# Second queue: [26, 22, 18, 14, 10, 6, 2]
# Best effort queue: [26, 25, 24, 11, 10, 6, 5, 2, 1, 0]
# ----------
# current step = 42
# -----
# Average delay of first queue: 13.9
# Average delay of second queue: 14.0
# Average delay of best-effort queue: 11.0
# -----
# Packets removed from first queue: 12
# Packets removed from second queue: 13
# Packets removed from best-effort queue: 17
# ----------
# First queue: [20, 19, 18, 17, 16, 15, 14, 13, 9, 8]
# Second queue: [27, 23, 19, 15, 11, 7, 3]
# Best effort queue: [26, 25, 12, 11, 7, 6, 3, 2, 1, 0]
# ----------
# current step = 43
# -----
# Average delay of first queue: 14.9
# Average delay of second queue: 15.0
# Average delay of best-effort queue: 9.3
# -----
# Packets removed from first queue: 12
# Packets removed from second queue: 13
# Packets removed from best-effort queue: 18
# ----------
# First queue: [21, 20, 19, 18, 17, 16, 15, 14, 10, 9]
# Second queue: [24, 20, 16, 12, 8, 4, 0]
# Best effort queue: [27, 26, 13, 12, 8, 7, 4, 3, 2, 1]
# ----------
# current step = 44
# -----
# Average delay of first queue: 15.9
# Average delay of second queue: 12.0
# Average delay of best-effort queue: 10.3
# -----
# Packets removed from first queue: 12
# Packets removed from second queue: 14
# Packets removed from best-effort queue: 18
# ----------
# First queue: [22, 21, 20, 19, 18, 17, 16, 15, 11, 10]
# Second queue: [25, 21, 17, 13, 9, 5, 1]
# Best effort queue: [27, 14, 13, 9, 8, 5, 4, 3, 2, 0]
# ----------
# current step = 45
# -----
# Average delay of first queue: 16.9
# Average delay of second queue: 13.0
# Average delay of best-effort queue: 8.5
# -----
# Packets removed from first queue: 12
# Packets removed from second queue: 14
# Packets removed from best-effort queue: 19
# ----------
# First queue: [23, 22, 21, 20, 19, 18, 17, 16, 12, 11]
# Second queue: [26, 22, 18, 14, 10, 6, 2]
# Best effort queue: [15, 14, 10, 9, 6, 5, 4, 3, 1, 0]
# ----------
# current step = 46
# -----
# Average delay of first queue: 17.9
# Average delay of second queue: 14.0
# Average delay of best-effort queue: 6.7
# -----
# Packets removed from first queue: 12
# Packets removed from second queue: 14
# Packets removed from best-effort queue: 20
# ----------
# First queue: [24, 23, 22, 21, 20, 19, 18, 17, 13, 12]
# Second queue: [23, 19, 15, 11, 7, 3]
# Best effort queue: [16, 15, 11, 10, 7, 6, 5, 4, 2, 1]
# ----------
# current step = 47
# -----
# Average delay of first queue: 18.9
# Average delay of second queue: 13.0
# Average delay of best-effort queue: 7.7
# -----
# Packets removed from first queue: 12
# Packets removed from second queue: 15
# Packets removed from best-effort queue: 20
# ----------
# First queue: [24, 23, 22, 21, 20, 19, 18, 14, 13, 0]
# Second queue: [24, 20, 16, 12, 8, 4, 0]
# Best effort queue: [17, 16, 12, 11, 8, 7, 6, 5, 3, 2]
# ----------
# current step = 48
# -----
# Average delay of first queue: 17.4
# Average delay of second queue: 12.0
# Average delay of best-effort queue: 8.7
# -----
# Packets removed from first queue: 13
# Packets removed from second queue: 15
# Packets removed from best-effort queue: 20
# ----------
# First queue: [25, 24, 23, 22, 21, 20, 19, 15, 14, 1]
# Second queue: [21, 17, 13, 9, 5, 1]
# Best effort queue: [18, 17, 13, 12, 9, 8, 7, 6, 4, 3]
# ----------
# current step = 49
# -----
# Average delay of first queue: 18.4
# Average delay of second queue: 11.0
# Average delay of best-effort queue: 9.7
# -----
# Packets removed from first queue: 13
# Packets removed from second queue: 16
# Packets removed from best-effort queue: 20
# ----------
# First queue: [25, 24, 23, 22, 21, 20, 16, 15, 2, 0]
# Second queue: [22, 18, 14, 10, 6, 2]
# Best effort queue: [19, 18, 14, 13, 10, 9, 8, 7, 5, 4]
# ----------
# current step = 50
# -----
# Average delay of first queue: 16.8
# Average delay of second queue: 12.0
# Average delay of best-effort queue: 10.7
# -----
# Packets removed from first queue: 14
# Packets removed from second queue: 16
# Packets removed from best-effort queue: 20
# -22

# %%
# predefine a mean delay for first queue, second queue and best effort queue. 
MEAN_DELAY_ONE = 4
MEAN_DELAY_TWO = 6
MEAN_DELAY_THREE = 10
